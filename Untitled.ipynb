# %%
import requests
import json
import pandas as pd

# %%
email = lilu216@hotmail.com
api

# %%
url = "https://aqs.epa.gov/data/api/qaBlanks/byState?email=test@aqs.api&key=test&param=88101&bdate=20180101&edate=20180131&state=01"

response = requests.get(url)
response.json()
# Out:
# {'Header': [{'status': 'Success',
#    'request_time': '2020-04-25T13:18:41-04:00',
#    'url': 'https://aqs.epa.gov/data/api/qaBlanks/byState?email=test@aqs.api&key=test&param=88101&bdate=20180101&edate=20180131&state=01',
#    'rows': 30}],
#  'Data': [{'state_code': '01',
#    'county_code': '073',
#    'site_number': '0023',
#    'parameter_code': '88101',
#    'poc': 1,
#    'parameter_name': 'PM2.5 - Local Conditions',
#    'blank_type': 'FIELD',
#    'date_local': '2018-01-08',
#    'time_local': '00:00',
#    'sample_measurement': 1.4,
#    'units_of_measure': 'Micrograms',
#    'sample_duration': '24 HOUR',
#    'detection_limit': None,
#    'uncertainty': None,
#    'method_type': 'FRM',
#    'method_code': '142',
#    'method': 'BGI Models PQ200-VSCC or PQ200A-VSCC - Gravimetric',
#    'date_of_last_change': '2019-02-13',
#    'qualifiers': None,
#    'latitude': 33.553056,
#    'longitude': -86.815,
#    'datum': 'WGS84',
#    'local_site_name': 'North Birmingham',
#    'address': "NO. B'HAM,SOU R.R., 3009 28TH ST. NO.",
#    'state_name': 'Alabama',
#    'county_name': 'Jefferson',
#    'city_name': 'Birmingham',
#    'cbsa_code': '13820',
#    'cbsa_name': 'Birmingham-Hoover, AL',
#    'csa_code': '142',
#    'csa_name': 'Birmingham-Hoover-Talladega, AL',
#    'tribal_code': None,
#    'tribe_name': None,
#    'monitor_type': 'SLAMS',
#    'pqao_code': '0550',
#    'pqao': 'Jefferson County, AL  Department Of Health',
#    'monitoring_agency_code': '0550',
#    'monitoring_agency': 'Jefferson County, AL  Department Of Health',
#    'analyzing_agency_code': '0550',
#    'analyzing_agency': 'Jefferson County, AL  Department Of Health',
#    'networks': 'NCORE'},
#   {'state_code': '01',
#    'county_code': '073',
#    'site_number': '2059',
#    'parameter_code': '88101',
#    'poc': 1,
#    'parameter_name': 'PM2.5 - Local Conditions',
#    'blank_type': 'FIELD',
#    'date_local': '2018-01-08',
#    'time_local': '00:00',
#    'sample_measurement': 0.4,
#    'units_of_measure': 'Micrograms',
#    'sample_duration': '24 HOUR',
#    'detection_limit': None,
#    'uncertainty': None,
#    'method_type': 'FRM',
#    'method_code': '142',
#    'method': 'BGI Models PQ200-VSCC or PQ200A-VSCC - Gravimetric',
#    'date_of_last_change': '2019-02-13',
#    'qualifiers': None,
#    'latitude': 33.521427,
#    'longitude': -86.844112,
#    'datum': 'WGS84',
#    'local_site_name': 'Arkadelphia/Near Road',
#    'address': '1110 5th Street West Birmingham, AL 35204',
#    'state_name': 'Alabama',
#    'county_name': 'Jefferson',
#    'city_name': 'Birmingham',
#    'cbsa_code': '13820',
#    'cbsa_name': 'Birmingham-Hoover, AL',
#    'csa_code': '142',
#    'csa_name': 'Birmingham-Hoover-Talladega, AL',
#    'tribal_code': None,
#    'tribe_name': None,
#    'monitor_type': 'SLAMS',
#    'pqao_code': '0550',
#    'pqao': 'Jefferson County, AL  Department Of Health',
#    'monitoring_agency_code': '0550',
#    'monitoring_agency': 'Jefferson County, AL  Department Of Health',
#    'analyzing_agency_code': '0550',
#    'analyzing_agency': 'Jefferson County, AL  Department Of Health',
#    'networks': 'NEAR ROAD'},
#   {'state_code': '01',
#    'county_code': '103',
#    'site_number': '0011',
#    'parameter_code': '88101',
#    'poc': 1,
#    'parameter_name': 'PM2.5 - Local Conditions',
#    'blank_type': 'FIELD',
#    'date_local': '2018-01-05',
#    'time_local': '00:01',
#    'sample_measurement': 3.0,
#    'units_of_measure': 'Micrograms',
#    'sample_duration': '24 HOUR',
#    'detection_limit': None,
#    'uncertainty': None,
#    'method_type': 'FRM',
#    'method_code': '145',
#    'method': 'R & P Model 2025 PM-2.5 Sequential Air Sampler w/VSCC - Gravimetric',
#    'date_of_last_change': '2019-02-13',
#    'qualifiers': None,
#    'latitude': 34.530717,
#    'longitude': -86.967536,
#    'datum': 'NAD83',
#    'local_site_name': 'DECATUR, Alabama',
#    'address': 'P.O. BOX 2224 WALLACE DEVELOPMENT CENTER. DECATUR, ALABAMA',
#    'state_name': 'Alabama',
#    'county_name': 'Morgan',
#    'city_name': 'Decatur',
#    'cbsa_code': '19460',
#    'cbsa_name': 'Decatur, AL',
#    'csa_code': '290',
#    'csa_name': 'Huntsville-Decatur-Albertville, AL',
#    'tribal_code': None,
#    'tribe_name': None,
#    'monitor_type': 'SLAMS',
#    'pqao_code': '0013',
#    'pqao': 'Al Dept Of Env Mgt',
#    'monitoring_agency_code': '0013',
#    'monitoring_agency': 'Al Dept Of Env Mgt',
#    'analyzing_agency_code': '0013',
#    'analyzing_agency': 'Al Dept Of Env Mgt',
#    'networks': None},
#   {'state_code': '01',
#    'county_code': '103',
#    'site_number': '0011',
#    'parameter_code': '88101',
#    'poc': 1,
#    'parameter_name': 'PM2.5 - Local Conditions',
#    'blank_type': 'TRIP',
#    'date_local': '2018-01-03',
#    'time_local': '00:00',
#    'sample_measurement': 3.0,
#    'units_of_measure': 'Micrograms',
#    'sample_duration': '24 HOUR',
#    'detection_limit': None,
#    'uncertainty': None,
#    'method_type': 'FRM',
#    'method_code': '145',
#    'method': 'R & P Model 2025 PM-2.5 Sequential Air Sampler w/VSCC - Gravimetric',
#    'date_of_last_change': '2019-02-13',
#    'qualifiers': None,
#    'latitude': 34.530717,
#    'longitude': -86.967536,
#    'datum': 'NAD83',
#    'local_site_name': 'DECATUR, Alabama',
#    'address': 'P.O. BOX 2224 WALLACE DEVELOPMENT CENTER. DECATUR, ALABAMA',
#    'state_name': 'Alabama',
#    'county_name': 'Morgan',
#    'city_name': 'Decatur',
#    'cbsa_code': '19460',
#    'cbsa_name': 'Decatur, AL',
#    'csa_code': '290',
#    'csa_name': 'Huntsville-Decatur-Albertville, AL',
#    'tribal_code': None,
#    'tribe_name': None,
#    'monitor_type': 'SLAMS',
#    'pqao_code': '0013',
#    'pqao': 'Al Dept Of Env Mgt',
#    'monitoring_agency_code': '0013',
#    'monitoring_agency': 'Al Dept Of Env Mgt',
#    'analyzing_agency_code': '0013',
#    'analyzing_agency': 'Al Dept Of Env Mgt',
#    'networks': None},
#   {'state_code': '01',
#    'county_code': '089',
#    'site_number': '0014',
#    'parameter_code': '88101',
#    'poc': 2,
#    'parameter_name': 'PM2.5 - Local Conditions',
#    'blank_type': 'FIELD',
#    'date_local': '2018-01-27',
#    'time_local': '00:00',
#    'sample_measurement': 2.0,
#    'units_of_measure': 'Micrograms',
#    'sample_duration': '24 HOUR',
#    'detection_limit': None,
#    'uncertainty': None,
#    'method_type': 'FRM',
#    'method_code': '145',
#    'method': 'R & P Model 2025 PM-2.5 Sequential Air Sampler w/VSCC - Gravimetric',
#    'date_of_last_change': '2019-02-13',
#    'qualifiers': None,
#    'latitude': 34.687761,
#    'longitude': -86.586362,
#    'datum': 'WGS84',
#    'local_site_name': 'HUNTSVILLE OLD AIRPORT',
#    'address': '2201 AIRPORT ROAD',
#    'state_name': 'Alabama',
#    'county_name': 'Madison',
#    'city_name': 'Huntsville',
#    'cbsa_code': '26620',
#    'cbsa_name': 'Huntsville, AL',
#    'csa_code': '290',
#    'csa_name': 'Huntsville-Decatur-Albertville, AL',
#    'tribal_code': None,
#    'tribe_name': None,
#    'monitor_type': 'SLAMS',
#    'pqao_code': '0300',
#    'pqao': 'City of Huntsville, Div of Natural Resources',
#    'monitoring_agency_code': '0300',
#    'monitoring_agency': 'City of Huntsville, Div of Natural Resources',
#    'analyzing_agency_code': '0300',
#    'analyzing_agency': 'City of Huntsville, Div of Natural Resources',
#    'networks': None},
#   {'state_code': '01',
#    'county_code': '089',
#    'site_number': '0014',
#    'parameter_code': '88101',
#    'poc': 2,
#    'parameter_name': 'PM2.5 - Local Conditions',
#    'blank_type': 'FIELD',
#    'date_local': '2018-01-09',
#    'time_local': '00:00',
#    'sample_measurement': 5.0,
#    'units_of_measure': 'Micrograms',
#    'sample_duration': '24 HOUR',
#    'detection_limit': None,
#    'uncertainty': None,
#    'method_type': 'FRM',
#    'method_code': '145',
#    'method': 'R & P Model 2025 PM-2.5 Sequential Air Sampler w/VSCC - Gravimetric',
#    'date_of_last_change': '2019-02-13',
#    'qualifiers': None,
#    'latitude': 34.687761,
#    'longitude': -86.586362,
#    'datum': 'WGS84',
#    'local_site_name': 'HUNTSVILLE OLD AIRPORT',
#    'address': '2201 AIRPORT ROAD',
#    'state_name': 'Alabama',
#    'county_name': 'Madison',
#    'city_name': 'Huntsville',
#    'cbsa_code': '26620',
#    'cbsa_name': 'Huntsville, AL',
#    'csa_code': '290',
#    'csa_name': 'Huntsville-Decatur-Albertville, AL',
#    'tribal_code': None,
#    'tribe_name': None,
#    'monitor_type': 'SLAMS',
#    'pqao_code': '0300',
#    'pqao': 'City of Huntsville, Div of Natural Resources',
#    'monitoring_agency_code': '0300',
#    'monitoring_agency': 'City of Huntsville, Div of Natural Resources',
#    'analyzing_agency_code': '0300',
#    'analyzing_agency': 'City of Huntsville, Div of Natural Resources',
#    'networks': None},
#   {'state_code': '01',
#    'county_code': '033',
#    'site_number': '1002',
#    'parameter_code': '88101',
#    'poc': 1,
#    'parameter_name': 'PM2.5 - Local Conditions',
#    'blank_type': 'FIELD',
#    'date_local': '2018-01-06',
#    'time_local': '00:01',
#    'sample_measurement': 1.0,
#    'units_of_measure': 'Micrograms',
#    'sample_duration': '24 HOUR',
#    'detection_limit': None,
#    'uncertainty': None,
#    'method_type': 'FRM',
#    'method_code': '145',
#    'method': 'R & P Model 2025 PM-2.5 Sequential Air Sampler w/VSCC - Gravimetric',
#    'date_of_last_change': '2019-02-13',
#    'qualifiers': None,
#    'latitude': 34.762619,
#    'longitude': -87.638097,
#    'datum': 'NAD83',
#    'local_site_name': 'MUSCLE SHOALS',
#    'address': 'WILSON DAM RD AND 2ND ST.',
#    'state_name': 'Alabama',
#    'county_name': 'Colbert',
#    'city_name': 'Muscle Shoals',
#    'cbsa_code': '22520',
#    'cbsa_name': 'Florence-Muscle Shoals, AL',
#    'csa_code': None,
#    'csa_name': None,
#    'tribal_code': None,
#    'tribe_name': None,
#    'monitor_type': None,
#    'pqao_code': '0013',
#    'pqao': 'Al Dept Of Env Mgt',
#    'monitoring_agency_code': '0013',
#    'monitoring_agency': 'Al Dept Of Env Mgt',
#    'analyzing_agency_code': '0013',
#    'analyzing_agency': 'Al Dept Of Env Mgt',
#    'networks': None},
#   {'state_code': '01',
#    'county_code': '049',
#    'site_number': '1003',
#    'parameter_code': '88101',
#    'poc': 1,
#    'parameter_name': 'PM2.5 - Local Conditions',
#    'blank_type': 'FIELD',
#    'date_local': '2018-01-06',
#    'time_local': '00:01',
#    'sample_measurement': 5.0,
#    'units_of_measure': 'Micrograms',
#    'sample_duration': '24 HOUR',
#    'detection_limit': None,
#    'uncertainty': None,
#    'method_type': 'FRM',
#    'method_code': '145',
#    'method': 'R & P Model 2025 PM-2.5 Sequential Air Sampler w/VSCC - Gravimetric',
#    'date_of_last_change': '2019-02-13',
#    'qualifiers': None,
#    'latitude': 34.288567,
#    'longitude': -85.969858,
#    'datum': 'NAD83',
#    'local_site_name': 'CROSSVILLE',
#    'address': '13112 HWY.68 , CROSSVILLE AL. 35962',
#    'state_name': 'Alabama',
#    'county_name': 'DeKalb',
#    'city_name': 'Crossville',
#    'cbsa_code': '22840',
#    'cbsa_name': 'Fort Payne, AL',
#    'csa_code': None,
#    'csa_name': None,
#    'tribal_code': None,
#    'tribe_name': None,
#    'monitor_type': 'SLAMS',
#    'pqao_code': '0013',
#    'pqao': 'Al Dept Of Env Mgt',
#    'monitoring_agency_code': '0013',
#    'monitoring_agency': 'Al Dept Of Env Mgt',
#    'analyzing_agency_code': '0013',
#    'analyzing_agency': 'Al Dept Of Env Mgt',
#    'networks': None},
#   {'state_code': '01',
#    'county_code': '049',
#    'site_number': '1003',
#    'parameter_code': '88101',
#    'poc': 1,
#    'parameter_name': 'PM2.5 - Local Conditions',
#    'blank_type': 'TRIP',
#    'date_local': '2018-01-03',
#    'time_local': '00:00',
#    'sample_measurement': 0.0,
#    'units_of_measure': 'Micrograms',
#    'sample_duration': '24 HOUR',
#    'detection_limit': None,
#    'uncertainty': None,
#    'method_type': 'FRM',
#    'method_code': '145',
#    'method': 'R & P Model 2025 PM-2.5 Sequential Air Sampler w/VSCC - Gravimetric',
#    'date_of_last_change': '2019-02-13',
#    'qualifiers': None,
#    'latitude': 34.288567,
#    'longitude': -85.969858,
#    'datum': 'NAD83',
#    'local_site_name': 'CROSSVILLE',
#    'address': '13112 HWY.68 , CROSSVILLE AL. 35962',
#    'state_name': 'Alabama',
#    'county_name': 'DeKalb',
#    'city_name': 'Crossville',
#    'cbsa_code': '22840',
#    'cbsa_name': 'Fort Payne, AL',
#    'csa_code': None,
#    'csa_name': None,
#    'tribal_code': None,
#    'tribe_name': None,
#    'monitor_type': 'SLAMS',
#    'pqao_code': '0013',
#    'pqao': 'Al Dept Of Env Mgt',
#    'monitoring_agency_code': '0013',
#    'monitoring_agency': 'Al Dept Of Env Mgt',
#    'analyzing_agency_code': '0013',
#    'analyzing_agency': 'Al Dept Of Env Mgt',
#    'networks': None},
#   {'state_code': '01',
#    'county_code': '055',
#    'site_number': '0010',
#    'parameter_code': '88101',
#    'poc': 1,
#    'parameter_name': 'PM2.5 - Local Conditions',
#    'blank_type': 'FIELD',
#    'date_local': '2018-01-06',
#    'time_local': '00:01',
#    'sample_measurement': 5.0,
#    'units_of_measure': 'Micrograms',
#    'sample_duration': '24 HOUR',
#    'detection_limit': None,
#    'uncertainty': None,
#    'method_type': 'FRM',
#    'method_code': '145',
#    'method': 'R & P Model 2025 PM-2.5 Sequential Air Sampler w/VSCC - Gravimetric',
#    'date_of_last_change': '2019-02-13',
#    'qualifiers': None,
#    'latitude': 33.991494,
#    'longitude': -85.992647,
#    'datum': 'NAD83',
#    'local_site_name': 'GADSDEN C. COLLEGE',
#    'address': '1001 WALLACE DRIVE, GADSDEN, AL 35902',
#    'state_name': 'Alabama',
#    'county_name': 'Etowah',
#    'city_name': 'Gadsden',
#    'cbsa_code': '23460',
#    'cbsa_name': 'Gadsden, AL',
#    'csa_code': None,
#    'csa_name': None,
#    'tribal_code': None,
#    'tribe_name': None,
#    'monitor_type': 'SLAMS',
#    'pqao_code': '0013',
#    'pqao': 'Al Dept Of Env Mgt',
#    'monitoring_agency_code': '0013',
#    'monitoring_agency': 'Al Dept Of Env Mgt',
#    'analyzing_agency_code': '0013',
#    'analyzing_agency': 'Al Dept Of Env Mgt',
#    'networks': None},
#   {'state_code': '01',
#    'county_code': '073',
#    'site_number': '1005',
#    'parameter_code': '88101',
#    'poc': 1,
#    'parameter_name': 'PM2.5 - Local Conditions',
#    'blank_type': 'FIELD',
#    'date_local': '2018-01-08',
#    'time_local': '00:00',
#    'sample_measurement': 1.4,
#    'units_of_measure': 'Micrograms',
#    'sample_duration': '24 HOUR',
#    'detection_limit': None,
#    'uncertainty': None,
#    'method_type': 'FRM',
#    'method_code': '142',
#    'method': 'BGI Models PQ200-VSCC or PQ200A-VSCC - Gravimetric',
#    'date_of_last_change': '2019-02-13',
#    'qualifiers': None,
#    'latitude': 33.331111,
#    'longitude': -87.003611,
#    'datum': 'WGS84',
#    'local_site_name': 'McAdory',
#    'address': ' ROUTE 8 MCADORY',
#    'state_name': 'Alabama',
#    'county_name': 'Jefferson',
#    'city_name': 'Not in a City',
#    'cbsa_code': '13820',
#    'cbsa_name': 'Birmingham-Hoover, AL',
#    'csa_code': '142',
#    'csa_name': 'Birmingham-Hoover-Talladega, AL',
#    'tribal_code': None,
#    'tribe_name': None,
#    'monitor_type': 'SPM',
#    'pqao_code': '0550',
#    'pqao': 'Jefferson County, AL  Department Of Health',
#    'monitoring_agency_code': '0550',
#    'monitoring_agency': 'Jefferson County, AL  Department Of Health',
#    'analyzing_agency_code': '0550',
#    'analyzing_agency': 'Jefferson County, AL  Department Of Health',
#    'networks': None},
#   {'state_code': '01',
#    'county_code': '101',
#    'site_number': '1002',
#    'parameter_code': '88101',
#    'poc': 1,
#    'parameter_name': 'PM2.5 - Local Conditions',
#    'blank_type': 'FIELD',
#    'date_local': '2018-01-06',
#    'time_local': '00:01',
#    'sample_measurement': -1.0,
#    'units_of_measure': 'Micrograms',
#    'sample_duration': '24 HOUR',
#    'detection_limit': None,
#    'uncertainty': None,
#    'method_type': 'FRM',
#    'method_code': '145',
#    'method': 'R & P Model 2025 PM-2.5 Sequential Air Sampler w/VSCC - Gravimetric',
#    'date_of_last_change': '2019-02-13',
#    'qualifiers': None,
#    'latitude': 32.412811,
#    'longitude': -86.263394,
#    'datum': 'NAD83',
#    'local_site_name': 'MOMS, ADEM',
#    'address': '1350 COLISEUM BLVD, MONTGOMERY, ALABAMA',
#    'state_name': 'Alabama',
#    'county_name': 'Montgomery',
#    'city_name': 'Montgomery',
#    'cbsa_code': '33860',
#    'cbsa_name': 'Montgomery, AL',
#    'csa_code': None,
#    'csa_name': None,
#    'tribal_code': None,
#    'tribe_name': None,
#    'monitor_type': 'SLAMS',
#    'pqao_code': '0013',
#    'pqao': 'Al Dept Of Env Mgt',
#    'monitoring_agency_code': '0013',
#    'monitoring_agency': 'Al Dept Of Env Mgt',
#    'analyzing_agency_code': '0013',
#    'analyzing_agency': 'Al Dept Of Env Mgt',
#    'networks': None},
#   {'state_code': '01',
#    'county_code': '069',
#    'site_number': '0003',
#    'parameter_code': '88101',
#    'poc': 1,
#    'parameter_name': 'PM2.5 - Local Conditions',
#    'blank_type': 'TRIP',
#    'date_local': '2018-01-03',
#    'time_local': '00:00',
#    'sample_measurement': -2.0,
#    'units_of_measure': 'Micrograms',
#    'sample_duration': '24 HOUR',
#    'detection_limit': None,
#    'uncertainty': None,
#    'method_type': 'FRM',
#    'method_code': '145',
#    'method': 'R & P Model 2025 PM-2.5 Sequential Air Sampler w/VSCC - Gravimetric',
#    'date_of_last_change': '2019-02-13',
#    'qualifiers': None,
#    'latitude': 31.224783,
#    'longitude': -85.390789,
#    'datum': 'NAD83',
#    'local_site_name': 'DOTHAN (CIVIC CENTER)',
#    'address': '126 NORTH ST. ANDREWS STREET (CIVIC CENTER)',
#    'state_name': 'Alabama',
#    'county_name': 'Houston',
#    'city_name': 'Dothan',
#    'cbsa_code': '20020',
#    'cbsa_name': 'Dothan, AL',
#    'csa_code': '222',
#    'csa_name': 'Dothan-Enterprise-Ozark, AL',
#    'tribal_code': None,
#    'tribe_name': None,
#    'monitor_type': None,
#    'pqao_code': '0013',
#    'pqao': 'Al Dept Of Env Mgt',
#    'monitoring_agency_code': '0013',
#    'monitoring_agency': 'Al Dept Of Env Mgt',
#    'analyzing_agency_code': '0013',
#    'analyzing_agency': 'Al Dept Of Env Mgt',
#    'networks': None},
#   {'state_code': '01',
#    'county_code': '069',
#    'site_number': '0003',
#    'parameter_code': '88101',
#    'poc': 1,
#    'parameter_name': 'PM2.5 - Local Conditions',
#    'blank_type': 'FIELD',
#    'date_local': '2018-01-06',
#    'time_local': '00:01',
#    'sample_measurement': 2.0,
#    'units_of_measure': 'Micrograms',
#    'sample_duration': '24 HOUR',
#    'detection_limit': None,
#    'uncertainty': None,
#    'method_type': 'FRM',
#    'method_code': '145',
#    'method': 'R & P Model 2025 PM-2.5 Sequential Air Sampler w/VSCC - Gravimetric',
#    'date_of_last_change': '2019-02-13',
#    'qualifiers': None,
#    'latitude': 31.224783,
#    'longitude': -85.390789,
#    'datum': 'NAD83',
#    'local_site_name': 'DOTHAN (CIVIC CENTER)',
#    'address': '126 NORTH ST. ANDREWS STREET (CIVIC CENTER)',
#    'state_name': 'Alabama',
#    'county_name': 'Houston',
#    'city_name': 'Dothan',
#    'cbsa_code': '20020',
#    'cbsa_name': 'Dothan, AL',
#    'csa_code': '222',
#    'csa_name': 'Dothan-Enterprise-Ozark, AL',
#    'tribal_code': None,
#    'tribe_name': None,
#    'monitor_type': None,
#    'pqao_code': '0013',
#    'pqao': 'Al Dept Of Env Mgt',
#    'monitoring_agency_code': '0013',
#    'monitoring_agency': 'Al Dept Of Env Mgt',
#    'analyzing_agency_code': '0013',
#    'analyzing_agency': 'Al Dept Of Env Mgt',
#    'networks': None},
#   {'state_code': '01',
#    'county_code': '113',
#    'site_number': '0003',
#    'parameter_code': '88101',
#    'poc': 2,
#    'parameter_name': 'PM2.5 - Local Conditions',
#    'blank_type': 'FIELD',
#    'date_local': '2018-01-06',
#    'time_local': '00:01',
#    'sample_measurement': 2.0,
#    'units_of_measure': 'Micrograms',
#    'sample_duration': '24 HOUR',
#    'detection_limit': None,
#    'uncertainty': None,
#    'method_type': 'FRM',
#    'method_code': '145',
#    'method': 'R & P Model 2025 PM-2.5 Sequential Air Sampler w/VSCC - Gravimetric',
#    'date_of_last_change': '2019-02-13',
#    'qualifiers': None,
#    'latitude': 32.437028,
#    'longitude': -84.999653,
#    'datum': 'NAD83',
#    'local_site_name': 'PHENIX CITY - SOUTH GIRARD SCHOOL',
#    'address': '510 6th Place South, Phenix City, Alabama  36869',
#    'state_name': 'Alabama',
#    'county_name': 'Russell',
#    'city_name': 'Phenix City',
#    'cbsa_code': '17980',
#    'cbsa_name': 'Columbus, GA-AL',
#    'csa_code': '194',
#    'csa_name': 'Columbus-Auburn-Opelika, GA-AL',
#    'tribal_code': None,
#    'tribe_name': None,
#    'monitor_type': 'SLAMS',
#    'pqao_code': '0013',
#    'pqao': 'Al Dept Of Env Mgt',
#    'monitoring_agency_code': '0013',
#    'monitoring_agency': 'Al Dept Of Env Mgt',
#    'analyzing_agency_code': '0013',
#    'analyzing_agency': 'Al Dept Of Env Mgt',
#    'networks': None},
#   {'state_code': '01',
#    'county_code': '101',
#    'site_number': '1002',
#    'parameter_code': '88101',
#    'poc': 2,
#    'parameter_name': 'PM2.5 - Local Conditions',
#    'blank_type': 'FIELD',
#    'date_local': '2018-01-09',
#    'time_local': '00:01',
#    'sample_measurement': 2.0,
#    'units_of_measure': 'Micrograms',
#    'sample_duration': '24 HOUR',
#    'detection_limit': None,
#    'uncertainty': None,
#    'method_type': 'FRM',
#    'method_code': '145',
#    'method': 'R & P Model 2025 PM-2.5 Sequential Air Sampler w/VSCC - Gravimetric',
#    'date_of_last_change': '2019-02-13',
#    'qualifiers': None,
#    'latitude': 32.412811,
#    'longitude': -86.263394,
#    'datum': 'NAD83',
#    'local_site_name': 'MOMS, ADEM',
#    'address': '1350 COLISEUM BLVD, MONTGOMERY, ALABAMA',
#    'state_name': 'Alabama',
#    'county_name': 'Montgomery',
#    'city_name': 'Montgomery',
#    'cbsa_code': '33860',
#    'cbsa_name': 'Montgomery, AL',
#    'csa_code': None,
#    'csa_name': None,
#    'tribal_code': None,
#    'tribe_name': None,
#    'monitor_type': 'SLAMS',
#    'pqao_code': '0013',
#    'pqao': 'Al Dept Of Env Mgt',
#    'monitoring_agency_code': '0013',
#    'monitoring_agency': 'Al Dept Of Env Mgt',
#    'analyzing_agency_code': '0013',
#    'analyzing_agency': 'Al Dept Of Env Mgt',
#    'networks': None},
#   {'state_code': '01',
#    'county_code': '097',
#    'site_number': '0003',
#    'parameter_code': '88101',
#    'poc': 1,
#    'parameter_name': 'PM2.5 - Local Conditions',
#    'blank_type': 'FIELD',
#    'date_local': '2018-01-03',
#    'time_local': '00:01',
#    'sample_measurement': 26.0,
#    'units_of_measure': 'Micrograms',
#    'sample_duration': '24 HOUR',
#    'detection_limit': None,
#    'uncertainty': None,
#    'method_type': 'FRM',
#    'method_code': '145',
#    'method': 'R & P Model 2025 PM-2.5 Sequential Air Sampler w/VSCC - Gravimetric',
#    'date_of_last_change': '2019-02-13',
#    'qualifiers': None,
#    'latitude': 30.770181,
#    'longitude': -88.087761,
#    'datum': 'NAD83',
#    'local_site_name': 'CHICKASAW',
#    'address': 'Iroquois and Azalea, CHICKASAW, MOBILE CO.,  ALABAMA',
#    'state_name': 'Alabama',
#    'county_name': 'Mobile',
#    'city_name': 'Chickasaw',
#    'cbsa_code': '33660',
#    'cbsa_name': 'Mobile, AL',
#    'csa_code': '380',
#    'csa_name': 'Mobile-Daphne-Fairhope, AL',
#    'tribal_code': None,
#    'tribe_name': None,
#    'monitor_type': 'SLAMS',
#    'pqao_code': '0013',
#    'pqao': 'Al Dept Of Env Mgt',
#    'monitoring_agency_code': '0013',
#    'monitoring_agency': 'Al Dept Of Env Mgt',
#    'analyzing_agency_code': '0013',
#    'analyzing_agency': 'Al Dept Of Env Mgt',
#    'networks': None},
#   {'state_code': '01',
#    'county_code': '027',
#    'site_number': '0001',
#    'parameter_code': '88101',
#    'poc': 1,
#    'parameter_name': 'PM2.5 - Local Conditions',
#    'blank_type': 'FIELD',
#    'date_local': '2018-01-06',
#    'time_local': '00:01',
#    'sample_measurement': 1.0,
#    'units_of_measure': 'Micrograms',
#    'sample_duration': '24 HOUR',
#    'detection_limit': None,
#    'uncertainty': None,
#    'method_type': 'FRM',
#    'method_code': '145',
#    'method': 'R & P Model 2025 PM-2.5 Sequential Air Sampler w/VSCC - Gravimetric',
#    'date_of_last_change': '2019-02-13',
#    'qualifiers': None,
#    'latitude': 33.284928,
#    'longitude': -85.803608,
#    'datum': 'NAD83',
#    'local_site_name': 'ASHLAND',
#    'address': 'ASHLAND AIRPORT',
#    'state_name': 'Alabama',
#    'county_name': 'Clay',
#    'city_name': 'Ashland',
#    'cbsa_code': None,
#    'cbsa_name': None,
#    'csa_code': None,
#    'csa_name': None,
#    'tribal_code': None,
#    'tribe_name': None,
#    'monitor_type': 'SLAMS',
#    'pqao_code': '0013',
#    'pqao': 'Al Dept Of Env Mgt',
#    'monitoring_agency_code': '0013',
#    'monitoring_agency': 'Al Dept Of Env Mgt',
#    'analyzing_agency_code': '0013',
#    'analyzing_agency': 'Al Dept Of Env Mgt',
#    'networks': None},
#   {'state_code': '01',
#    'county_code': '027',
#    'site_number': '0001',
#    'parameter_code': '88101',
#    'poc': 1,
#    'parameter_name': 'PM2.5 - Local Conditions',
#    'blank_type': 'TRIP',
#    'date_local': '2018-01-03',
#    'time_local': '00:00',
#    'sample_measurement': -4.0,
#    'units_of_measure': 'Micrograms',
#    'sample_duration': '24 HOUR',
#    'detection_limit': None,
#    'uncertainty': None,
#    'method_type': 'FRM',
#    'method_code': '145',
#    'method': 'R & P Model 2025 PM-2.5 Sequential Air Sampler w/VSCC - Gravimetric',
#    'date_of_last_change': '2019-02-13',
#    'qualifiers': None,
#    'latitude': 33.284928,
#    'longitude': -85.803608,
#    'datum': 'NAD83',
#    'local_site_name': 'ASHLAND',
#    'address': 'ASHLAND AIRPORT',
#    'state_name': 'Alabama',
#    'county_name': 'Clay',
#    'city_name': 'Ashland',
#    'cbsa_code': None,
#    'cbsa_name': None,
#    'csa_code': None,
#    'csa_name': None,
#    'tribal_code': None,
#    'tribe_name': None,
#    'monitor_type': 'SLAMS',
#    'pqao_code': '0013',
#    'pqao': 'Al Dept Of Env Mgt',
#    'monitoring_agency_code': '0013',
#    'monitoring_agency': 'Al Dept Of Env Mgt',
#    'analyzing_agency_code': '0013',
#    'analyzing_agency': 'Al Dept Of Env Mgt',
#    'networks': None},
#   {'state_code': '01',
#    'county_code': '089',
#    'site_number': '0014',
#    'parameter_code': '88101',
#    'poc': 1,
#    'parameter_name': 'PM2.5 - Local Conditions',
#    'blank_type': 'FIELD',
#    'date_local': '2018-01-15',
#    'time_local': '00:00',
#    'sample_measurement': 3.0,
#    'units_of_measure': 'Micrograms',
#    'sample_duration': '24 HOUR',
#    'detection_limit': None,
#    'uncertainty': None,
#    'method_type': 'FRM',
#    'method_code': '145',
#    'method': 'R & P Model 2025 PM-2.5 Sequential Air Sampler w/VSCC - Gravimetric',
#    'date_of_last_change': '2019-02-13',
#    'qualifiers': None,
#    'latitude': 34.687761,
#    'longitude': -86.586362,
#    'datum': 'WGS84',
#    'local_site_name': 'HUNTSVILLE OLD AIRPORT',
#    'address': '2201 AIRPORT ROAD',
#    'state_name': 'Alabama',
#    'county_name': 'Madison',
#    'city_name': 'Huntsville',
#    'cbsa_code': '26620',
#    'cbsa_name': 'Huntsville, AL',
#    'csa_code': '290',
#    'csa_name': 'Huntsville-Decatur-Albertville, AL',
#    'tribal_code': None,
#    'tribe_name': None,
#    'monitor_type': 'SLAMS',
#    'pqao_code': '0300',
#    'pqao': 'City of Huntsville, Div of Natural Resources',
#    'monitoring_agency_code': '0300',
#    'monitoring_agency': 'City of Huntsville, Div of Natural Resources',
#    'analyzing_agency_code': '0300',
#    'analyzing_agency': 'City of Huntsville, Div of Natural Resources',
#    'networks': None},
#   {'state_code': '01',
#    'county_code': '089',
#    'site_number': '0014',
#    'parameter_code': '88101',
#    'poc': 1,
#    'parameter_name': 'PM2.5 - Local Conditions',
#    'blank_type': 'FIELD',
#    'date_local': '2018-01-03',
#    'time_local': '00:00',
#    'sample_measurement': 5.0,
#    'units_of_measure': 'Micrograms',
#    'sample_duration': '24 HOUR',
#    'detection_limit': None,
#    'uncertainty': None,
#    'method_type': 'FRM',
#    'method_code': '145',
#    'method': 'R & P Model 2025 PM-2.5 Sequential Air Sampler w/VSCC - Gravimetric',
#    'date_of_last_change': '2019-02-13',
#    'qualifiers': None,
#    'latitude': 34.687761,
#    'longitude': -86.586362,
#    'datum': 'WGS84',
#    'local_site_name': 'HUNTSVILLE OLD AIRPORT',
#    'address': '2201 AIRPORT ROAD',
#    'state_name': 'Alabama',
#    'county_name': 'Madison',
#    'city_name': 'Huntsville',
#    'cbsa_code': '26620',
#    'cbsa_name': 'Huntsville, AL',
#    'csa_code': '290',
#    'csa_name': 'Huntsville-Decatur-Albertville, AL',
#    'tribal_code': None,
#    'tribe_name': None,
#    'monitor_type': 'SLAMS',
#    'pqao_code': '0300',
#    'pqao': 'City of Huntsville, Div of Natural Resources',
#    'monitoring_agency_code': '0300',
#    'monitoring_agency': 'City of Huntsville, Div of Natural Resources',
#    'analyzing_agency_code': '0300',
#    'analyzing_agency': 'City of Huntsville, Div of Natural Resources',
#    'networks': None},
#   {'state_code': '01',
#    'county_code': '089',
#    'site_number': '0014',
#    'parameter_code': '88101',
#    'poc': 1,
#    'parameter_name': 'PM2.5 - Local Conditions',
#    'blank_type': 'FIELD',
#    'date_local': '2018-01-09',
#    'time_local': '00:00',
#    'sample_measurement': 3.0,
#    'units_of_measure': 'Micrograms',
#    'sample_duration': '24 HOUR',
#    'detection_limit': None,
#    'uncertainty': None,
#    'method_type': 'FRM',
#    'method_code': '145',
#    'method': 'R & P Model 2025 PM-2.5 Sequential Air Sampler w/VSCC - Gravimetric',
#    'date_of_last_change': '2019-02-13',
#    'qualifiers': None,
#    'latitude': 34.687761,
#    'longitude': -86.586362,
#    'datum': 'WGS84',
#    'local_site_name': 'HUNTSVILLE OLD AIRPORT',
#    'address': '2201 AIRPORT ROAD',
#    'state_name': 'Alabama',
#    'county_name': 'Madison',
#    'city_name': 'Huntsville',
#    'cbsa_code': '26620',
#    'cbsa_name': 'Huntsville, AL',
#    'csa_code': '290',
#    'csa_name': 'Huntsville-Decatur-Albertville, AL',
#    'tribal_code': None,
#    'tribe_name': None,
#    'monitor_type': 'SLAMS',
#    'pqao_code': '0300',
#    'pqao': 'City of Huntsville, Div of Natural Resources',
#    'monitoring_agency_code': '0300',
#    'monitoring_agency': 'City of Huntsville, Div of Natural Resources',
#    'analyzing_agency_code': '0300',
#    'analyzing_agency': 'City of Huntsville, Div of Natural Resources',
#    'networks': None},
#   {'state_code': '01',
#    'county_code': '089',
#    'site_number': '0014',
#    'parameter_code': '88101',
#    'poc': 1,
#    'parameter_name': 'PM2.5 - Local Conditions',
#    'blank_type': 'FIELD',
#    'date_local': '2018-01-27',
#    'time_local': '00:00',
#    'sample_measurement': 3.0,
#    'units_of_measure': 'Micrograms',
#    'sample_duration': '24 HOUR',
#    'detection_limit': None,
#    'uncertainty': None,
#    'method_type': 'FRM',
#    'method_code': '145',
#    'method': 'R & P Model 2025 PM-2.5 Sequential Air Sampler w/VSCC - Gravimetric',
#    'date_of_last_change': '2019-02-13',
#    'qualifiers': None,
#    'latitude': 34.687761,
#    'longitude': -86.586362,
#    'datum': 'WGS84',
#    'local_site_name': 'HUNTSVILLE OLD AIRPORT',
#    'address': '2201 AIRPORT ROAD',
#    'state_name': 'Alabama',
#    'county_name': 'Madison',
#    'city_name': 'Huntsville',
#    'cbsa_code': '26620',
#    'cbsa_name': 'Huntsville, AL',
#    'csa_code': '290',
#    'csa_name': 'Huntsville-Decatur-Albertville, AL',
#    'tribal_code': None,
#    'tribe_name': None,
#    'monitor_type': 'SLAMS',
#    'pqao_code': '0300',
#    'pqao': 'City of Huntsville, Div of Natural Resources',
#    'monitoring_agency_code': '0300',
#    'monitoring_agency': 'City of Huntsville, Div of Natural Resources',
#    'analyzing_agency_code': '0300',
#    'analyzing_agency': 'City of Huntsville, Div of Natural Resources',
#    'networks': None},
#   {'state_code': '01',
#    'county_code': '113',
#    'site_number': '0003',
#    'parameter_code': '88101',
#    'poc': 1,
#    'parameter_name': 'PM2.5 - Local Conditions',
#    'blank_type': 'TRIP',
#    'date_local': '2018-01-04',
#    'time_local': '00:00',
#    'sample_measurement': -1.0,
#    'units_of_measure': 'Micrograms',
#    'sample_duration': '24 HOUR',
#    'detection_limit': None,
#    'uncertainty': None,
#    'method_type': 'FRM',
#    'method_code': '145',
#    'method': 'R & P Model 2025 PM-2.5 Sequential Air Sampler w/VSCC - Gravimetric',
#    'date_of_last_change': '2019-02-13',
#    'qualifiers': None,
#    'latitude': 32.437028,
#    'longitude': -84.999653,
#    'datum': 'NAD83',
#    'local_site_name': 'PHENIX CITY - SOUTH GIRARD SCHOOL',
#    'address': '510 6th Place South, Phenix City, Alabama  36869',
#    'state_name': 'Alabama',
#    'county_name': 'Russell',
#    'city_name': 'Phenix City',
#    'cbsa_code': '17980',
#    'cbsa_name': 'Columbus, GA-AL',
#    'csa_code': '194',
#    'csa_name': 'Columbus-Auburn-Opelika, GA-AL',
#    'tribal_code': None,
#    'tribe_name': None,
#    'monitor_type': 'SLAMS',
#    'pqao_code': '0013',
#    'pqao': 'Al Dept Of Env Mgt',
#    'monitoring_agency_code': '0013',
#    'monitoring_agency': 'Al Dept Of Env Mgt',
#    'analyzing_agency_code': '0013',
#    'analyzing_agency': 'Al Dept Of Env Mgt',
#    'networks': None},
#   {'state_code': '01',
#    'county_code': '113',
#    'site_number': '0003',
#    'parameter_code': '88101',
#    'poc': 1,
#    'parameter_name': 'PM2.5 - Local Conditions',
#    'blank_type': 'FIELD',
#    'date_local': '2018-01-04',
#    'time_local': '00:01',
#    'sample_measurement': 1.0,
#    'units_of_measure': 'Micrograms',
#    'sample_duration': '24 HOUR',
#    'detection_limit': None,
#    'uncertainty': None,
#    'method_type': 'FRM',
#    'method_code': '145',
#    'method': 'R & P Model 2025 PM-2.5 Sequential Air Sampler w/VSCC - Gravimetric',
#    'date_of_last_change': '2019-02-13',
#    'qualifiers': None,
#    'latitude': 32.437028,
#    'longitude': -84.999653,
#    'datum': 'NAD83',
#    'local_site_name': 'PHENIX CITY - SOUTH GIRARD SCHOOL',
#    'address': '510 6th Place South, Phenix City, Alabama  36869',
#    'state_name': 'Alabama',
#    'county_name': 'Russell',
#    'city_name': 'Phenix City',
#    'cbsa_code': '17980',
#    'cbsa_name': 'Columbus, GA-AL',
#    'csa_code': '194',
#    'csa_name': 'Columbus-Auburn-Opelika, GA-AL',
#    'tribal_code': None,
#    'tribe_name': None,
#    'monitor_type': 'SLAMS',
#    'pqao_code': '0013',
#    'pqao': 'Al Dept Of Env Mgt',
#    'monitoring_agency_code': '0013',
#    'monitoring_agency': 'Al Dept Of Env Mgt',
#    'analyzing_agency_code': '0013',
#    'analyzing_agency': 'Al Dept Of Env Mgt',
#    'networks': None},
#   {'state_code': '01',
#    'county_code': '073',
#    'site_number': '1010',
#    'parameter_code': '88101',
#    'poc': 1,
#    'parameter_name': 'PM2.5 - Local Conditions',
#    'blank_type': 'FIELD',
#    'date_local': '2018-01-08',
#    'time_local': '00:00',
#    'sample_measurement': 1.3,
#    'units_of_measure': 'Micrograms',
#    'sample_duration': '24 HOUR',
#    'detection_limit': None,
#    'uncertainty': None,
#    'method_type': 'FRM',
#    'method_code': '142',
#    'method': 'BGI Models PQ200-VSCC or PQ200A-VSCC - Gravimetric',
#    'date_of_last_change': '2019-02-13',
#    'qualifiers': None,
#    'latitude': 33.545278,
#    'longitude': -86.549167,
#    'datum': 'WGS84',
#    'local_site_name': 'Leeds',
#    'address': ' 201 ASHVILLE ROAD',
#    'state_name': 'Alabama',
#    'county_name': 'Jefferson',
#    'city_name': 'Leeds',
#    'cbsa_code': '13820',
#    'cbsa_name': 'Birmingham-Hoover, AL',
#    'csa_code': '142',
#    'csa_name': 'Birmingham-Hoover-Talladega, AL',
#    'tribal_code': None,
#    'tribe_name': None,
#    'monitor_type': 'SPM',
#    'pqao_code': '0550',
#    'pqao': 'Jefferson County, AL  Department Of Health',
#    'monitoring_agency_code': '0550',
#    'monitoring_agency': 'Jefferson County, AL  Department Of Health',
#    'analyzing_agency_code': '0550',
#    'analyzing_agency': 'Jefferson County, AL  Department Of Health',
#    'networks': None},
#   {'state_code': '01',
#    'county_code': '125',
#    'site_number': '0004',
#    'parameter_code': '88101',
#    'poc': 1,
#    'parameter_name': 'PM2.5 - Local Conditions',
#    'blank_type': 'TRIP',
#    'date_local': '2018-01-04',
#    'time_local': '00:00',
#    'sample_measurement': 2.0,
#    'units_of_measure': 'Micrograms',
#    'sample_duration': '24 HOUR',
#    'detection_limit': None,
#    'uncertainty': None,
#    'method_type': 'FRM',
#    'method_code': '145',
#    'method': 'R & P Model 2025 PM-2.5 Sequential Air Sampler w/VSCC - Gravimetric',
#    'date_of_last_change': '2019-02-13',
#    'qualifiers': None,
#    'latitude': 33.189931,
#    'longitude': -87.484189,
#    'datum': 'NAD83',
#    'local_site_name': 'VA, TUSCALOOSA',
#    'address': '3701 LOOP ROAD EAST',
#    'state_name': 'Alabama',
#    'county_name': 'Tuscaloosa',
#    'city_name': 'Tuscaloosa',
#    'cbsa_code': '46220',
#    'cbsa_name': 'Tuscaloosa, AL',
#    'csa_code': None,
#    'csa_name': None,
#    'tribal_code': None,
#    'tribe_name': None,
#    'monitor_type': 'SLAMS',
#    'pqao_code': '0013',
#    'pqao': 'Al Dept Of Env Mgt',
#    'monitoring_agency_code': '0013',
#    'monitoring_agency': 'Al Dept Of Env Mgt',
#    'analyzing_agency_code': '0013',
#    'analyzing_agency': 'Al Dept Of Env Mgt',
#    'networks': None},
#   {'state_code': '01',
#    'county_code': '125',
#    'site_number': '0004',
#    'parameter_code': '88101',
#    'poc': 1,
#    'parameter_name': 'PM2.5 - Local Conditions',
#    'blank_type': 'FIELD',
#    'date_local': '2018-01-04',
#    'time_local': '00:01',
#    'sample_measurement': 3.0,
#    'units_of_measure': 'Micrograms',
#    'sample_duration': '24 HOUR',
#    'detection_limit': None,
#    'uncertainty': None,
#    'method_type': 'FRM',
#    'method_code': '145',
#    'method': 'R & P Model 2025 PM-2.5 Sequential Air Sampler w/VSCC - Gravimetric',
#    'date_of_last_change': '2019-02-13',
#    'qualifiers': None,
#    'latitude': 33.189931,
#    'longitude': -87.484189,
#    'datum': 'NAD83',
#    'local_site_name': 'VA, TUSCALOOSA',
#    'address': '3701 LOOP ROAD EAST',
#    'state_name': 'Alabama',
#    'county_name': 'Tuscaloosa',
#    'city_name': 'Tuscaloosa',
#    'cbsa_code': '46220',
#    'cbsa_name': 'Tuscaloosa, AL',
#    'csa_code': None,
#    'csa_name': None,
#    'tribal_code': None,
#    'tribe_name': None,
#    'monitor_type': 'SLAMS',
#    'pqao_code': '0013',
#    'pqao': 'Al Dept Of Env Mgt',
#    'monitoring_agency_code': '0013',
#    'monitoring_agency': 'Al Dept Of Env Mgt',
#    'analyzing_agency_code': '0013',
#    'analyzing_agency': 'Al Dept Of Env Mgt',
#    'networks': None},
#   {'state_code': '01',
#    'county_code': '073',
#    'site_number': '2003',
#    'parameter_code': '88101',
#    'poc': 1,
#    'parameter_name': 'PM2.5 - Local Conditions',
#    'blank_type': 'FIELD',
#    'date_local': '2018-01-08',
#    'time_local': '00:00',
#    'sample_measurement': 8.3,
#    'units_of_measure': 'Micrograms',
#    'sample_duration': '24 HOUR',
#    'detection_limit': None,
#    'uncertainty': None,
#    'method_type': 'FRM',
#    'method_code': '142',
#    'method': 'BGI Models PQ200-VSCC or PQ200A-VSCC - Gravimetric',
#    'date_of_last_change': '2019-02-13',
#    'qualifiers': None,
#    'latitude': 33.499722,
#    'longitude': -86.924167,
#    'datum': 'WGS84',
#    'local_site_name': 'Wylam',
#    'address': '1242 JERSEY ST WYLAM AL',
#    'state_name': 'Alabama',
#    'county_name': 'Jefferson',
#    'city_name': 'Birmingham',
#    'cbsa_code': '13820',
#    'cbsa_name': 'Birmingham-Hoover, AL',
#    'csa_code': '142',
#    'csa_name': 'Birmingham-Hoover-Talladega, AL',
#    'tribal_code': None,
#    'tribe_name': None,
#    'monitor_type': 'SLAMS',
#    'pqao_code': '0550',
#    'pqao': 'Jefferson County, AL  Department Of Health',
#    'monitoring_agency_code': '0550',
#    'monitoring_agency': 'Jefferson County, AL  Department Of Health',
#    'analyzing_agency_code': '0550',
#    'analyzing_agency': 'Jefferson County, AL  Department Of Health',
#    'networks': None},
#   {'state_code': '01',
#    'county_code': '003',
#    'site_number': '0010',
#    'parameter_code': '88101',
#    'poc': 1,
#    'parameter_name': 'PM2.5 - Local Conditions',
#    'blank_type': 'FIELD',
#    'date_local': '2018-01-03',
#    'time_local': '00:01',
#    'sample_measurement': 3.0,
#    'units_of_measure': 'Micrograms',
#    'sample_duration': '24 HOUR',
#    'detection_limit': None,
#    'uncertainty': None,
#    'method_type': 'FRM',
#    'method_code': '145',
#    'method': 'R & P Model 2025 PM-2.5 Sequential Air Sampler w/VSCC - Gravimetric',
#    'date_of_last_change': '2019-02-13',
#    'qualifiers': None,
#    'latitude': 30.497478,
#    'longitude': -87.880258,
#    'datum': 'NAD83',
#    'local_site_name': 'FAIRHOPE, Alabama',
#    'address': 'FAIRHOPE HIGH SCHOOL, 1 PIRATE DRIVE, FAIRHOPE,  ALABAMA',
#    'state_name': 'Alabama',
#    'county_name': 'Baldwin',
#    'city_name': 'Fairhope',
#    'cbsa_code': '19300',
#    'cbsa_name': 'Daphne-Fairhope-Foley, AL',
#    'csa_code': '380',
#    'csa_name': 'Mobile-Daphne-Fairhope, AL',
#    'tribal_code': None,
#    'tribe_name': None,
#    'monitor_type': 'SLAMS',
#    'pqao_code': '0013',
#    'pqao': 'Al Dept Of Env Mgt',
#    'monitoring_agency_code': '0013',
#    'monitoring_agency': 'Al Dept Of Env Mgt',
#    'analyzing_agency_code': '0013',
#    'analyzing_agency': 'Al Dept Of Env Mgt',
#    'networks': None}]}
