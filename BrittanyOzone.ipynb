# %%
import requests
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import linregress
import scipy.stats as st

# %%
email = "lilu216@hotmail.com"
api&key = baygoose48

test_url =" https://aqs.epa.gov/data/api/list/states?email=test@aqs.api&key=test"
#test_2_url = "url": "https://aqs.epa.gov/data/api/annualData/byState?email=lilu216@hotmail.com&key=baygoose48&param=45201&bdate=20180101&edate=20181231&state=37"
criteria = "https://aqs.epa.gov/data/api/list/parametersByClass?email=test@aqs.api&key=test&pc=CRITERIA"
# Out:
#   File "<ipython-input-2-05be2b60c47a>", line 2
#     api&key = baygoose48
#                         ^
# SyntaxError: can't assign to operator

# %%
url = "https://aqs.epa.gov/data/api/qaBlanks/byState?email=test@aqs.api&key=test&param=88101&bdate=20170101&edate=20170131&state=01"
url_alabama_co = "https://aqs.epa.gov/data/api/annualData/byState?email=lilu216@hotmail.com&key=baygoose48&param=44201&bdate=20170101&edate=20171231&state=01"
response = requests.get(url_alabama_co).json()
print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# {
#     "Data": [
#         {
#             "arithmetic_mean": 0.042644,
#             "cbsa": "Birmingham-Hoover, AL",
#             "cbsa_code": "13820",
#             "certification_indicator": "Certified",
#             "city": "Birmingham",
#             "county": "Jefferson",
#             "county_code": "073",
#             "date_of_last_change": "2018-07-20",
#             "datum": "WGS84",
#             "event_type": "No Events",
#             "exceptional_data_count": 0,
#             "fiftieth_percentile": 0.043,
#             "first_max_datetime": "2017-05-15 13:00",
#             "first_max_n_o_datetime": null,
#             "first_max_nonoverlap_value": null,
#             "first_max_value": 0.094,
#             "fourth_max_datetime": "2017-05-10 15:00",
#             "fourth_max_value": 0.069,
#             "latitude": 33.553056,
#             "local_site_name": "North Birmingham",
#             "longitude": -86.815,
#             "method": "INSTRUMENTAL - ULTRA VIOLET ABSORPTION",
#             "metric_used": "Daily maxima of observed hourly values (between 9:00 AM and 8:00 PM)",
#             "ninetieth_percentile": 0.057,
#             "ninety_eighth_percentile": 0.067,
#             "ninety_fifth_percentile": 0.061,
#             "ninety_ninth_percentile": 0.069,
#             "null_observation_count": 988,
#             "observation_count": 7772,
#             "observation_percent": 91.0,
#             "parameter": "Ozone",
#             "parameter_code": "44201",
#             "poc": 1,
#             "pollutant_standard": "Ozone 1-hour 1979",
#             "primary_exceedance_count": 0,
#             "required_day_count": 365,
#             "sample_duration": "1 HOUR",
#             "second_max_datetime": "2017-10-13 16:00",
#             "second_max_n_o_datetime": null,
#             "second_max_nonoverlap_value": null,
#             "second_max_value": 0.076,
#             "secondary_exceedance_count": 0,
#             "seventy_fifth_percentile": 0.051,
#             "site_address": "NO. B'HAM,SOU R.R., 3009 28TH ST. NO.",
#             "site_number": "0023",
#             "standard_deviation": 0.012163,
#             "state": "Alabama",
#             "state_code": "01",
#             "tenth_percentile": 0.025,
#             "third_max_datetime": "2017-08-01 13:00",
#             "third_max_value": 0.072,
#             "units_of_measure": "Parts per million",
#             "valid_day_count": 331,
#             "validity_indicator": "Y",
#             "year": 2017
#         },
#         {
#             "arithmetic_mean": 0.037255,
#             "cbsa": "Birmingham-Hoover, AL",
#             "cbsa_code": "13820",
#             "certification_indicator": "Certified",
#             "city": "Birmingham",
#             "county": "Jefferson",
#             "county_code": "073",
#             "date_of_last_change": "2018-07-20",
#             "datum": "WGS84",
#             "event_type": "No Events",
#             "exceptional_data_count": 0,
#             "fiftieth_percentile": 0.038,
#             "first_max_datetime": "2017-05-15 10:00",
#             "first_max_n_o_datetime": null,
#             "first_max_nonoverlap_value": null,
#             "first_max_value": 0.078,
#             "fourth_max_datetime": "2017-07-10 09:00",
#             "fourth_max_value": 0.06,
#             "latitude": 33.553056,
#             "local_site_name": "North Birmingham",
#             "longitude": -86.815,
#             "method": null,
#             "metric_used": "Daily maximum of 8 hour running average of observed hourly values",
#             "ninetieth_percentile": 0.052,
#             "ninety_eighth_percentile": 0.058,
#             "ninety_fifth_percentile": 0.055,
#             "ninety_ninth_percentile": 0.06,
#             "null_observation_count": 0,
#             "observation_count": 7778,
#             "observation_percent": 86.0,
#             "parameter": "Ozone",
#             "parameter_code": "44201",
#             "poc": 1,
#             "pollutant_standard": "Ozone 8-Hour 1997",
#             "primary_exceedance_count": 0,
#             "required_day_count": 365,
#             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#             "second_max_datetime": "2017-08-01 10:00",
#             "second_max_n_o_datetime": null,
#             "second_max_nonoverlap_value": null,
#             "second_max_value": 0.066,
#             "secondary_exceedance_count": 0,
#             "seventy_fifth_percentile": 0.046,
#             "site_address": "NO. B'HAM,SOU R.R., 3009 28TH ST. NO.",
#             "site_number": "0023",
#             "standard_deviation": 0.011528,
#             "state": "Alabama",
#             "state_code": "01",
#             "tenth_percentile": 0.022,
#             "third_max_datetime": "2017-04-13 10:00",
#             "third_max_value": 0.062,
#             "units_of_measure": "Parts per million",
#             "valid_day_count": 314,
#             "validity_indicator": "Y",
#             "year": 2017
#         },
#         {
#             "arithmetic_mean": 0.037255,
#             "cbsa": "Birmingham-Hoover, AL",
#             "cbsa_code": "13820",
#             "certification_indicator": "Certified",
#             "city": "Birmingham",
#             "county": "Jefferson",
#             "county_code": "073",
#             "date_of_last_change": "2018-07-20",
#             "datum": "WGS84",
#             "event_type": "No Events",
#             "exceptional_data_count": 0,
#             "fiftieth_percentile": 0.038,
#             "first_max_datetime": "2017-05-15 10:00",
#             "first_max_n_o_datetime": null,
#             "first_max_nonoverlap_value": null,
#             "first_max_value": 0.078,
#             "fourth_max_datetime": "2017-07-10 09:00",
#             "fourth_max_value": 0.06,
#             "latitude": 33.553056,
#             "local_site_name": "North Birmingham",
#             "longitude": -86.815,
#             "method": null,
#             "metric_used": "Daily maximum of 8 hour running average of observed hourly values",
#             "ninetieth_percentile": 0.052,
#             "ninety_eighth_percentile": 0.058,
#             "ninety_fifth_percentile": 0.055,
#             "ninety_ninth_percentile": 0.06,
#             "null_observation_count": 0,
#             "observation_count": 7778,
#             "observation_percent": 86.0,
#             "parameter": "Ozone",
#             "parameter_code": "44201",
#             "poc": 1,
#             "pollutant_standard": "Ozone 8-Hour 2008",
#             "primary_exceedance_count": 1,
#             "required_day_count": 365,
#             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#             "second_max_datetime": "2017-08-01 10:00",
#             "second_max_n_o_datetime": null,
#             "second_max_nonoverlap_value": null,
#             "second_max_value": 0.066,
#             "secondary_exceedance_count": 1,
#             "seventy_fifth_percentile": 0.046,
#             "site_address": "NO. B'HAM,SOU R.R., 3009 28TH ST. NO.",
#             "site_number": "0023",
#             "standard_deviation": 0.011528,
#             "state": "Alabama",
#             "state_code": "01",
#             "tenth_percentile": 0.022,
#             "third_max_datetime": "2017-04-13 10:00",
#             "third_max_value": 0.062,
#             "units_of_measure": "Parts per million",
#             "valid_day_count": 314,
#             "validity_indicator": "Y",
#             "year": 2017
#         },
#         {
#             "arithmetic_mean": 0.037174,
#             "cbsa": "Birmingham-Hoover, AL",
#             "cbsa_code": "13820",
#             "certification_indicator": "Certified",
#             "city": "Birmingham",
#             "county": "Jefferson",
#             "county_code": "073",
#             "date_of_last_change": "2018-07-20",
#             "datum": "WGS84",
#             "event_type": "No Events",
#             "exceptional_data_count": 0,
#             "fiftieth_percentile": 0.038,
#             "first_max_datetime": "2017-05-15 10:00",
#             "first_max_n_o_datetime": null,
#             "first_max_nonoverlap_value": null,
#             "first_max_value": 0.078,
#             "fourth_max_datetime": "2017-07-10 09:00",
#             "fourth_max_value": 0.06,
#             "latitude": 33.553056,
#             "local_site_name": "North Birmingham",
#             "longitude": -86.815,
#             "method": null,
#             "metric_used": "Daily maximum of 8-hour running average",
#             "ninetieth_percentile": 0.052,
#             "ninety_eighth_percentile": 0.058,
#             "ninety_fifth_percentile": 0.055,
#             "ninety_ninth_percentile": 0.06,
#             "null_observation_count": 0,
#             "observation_count": 5528,
#             "observation_percent": 83.0,
#             "parameter": "Ozone",
#             "parameter_code": "44201",
#             "poc": 1,
#             "pollutant_standard": "Ozone 8-hour 2015",
#             "primary_exceedance_count": 1,
#             "required_day_count": 365,
#             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#             "second_max_datetime": "2017-08-01 10:00",
#             "second_max_n_o_datetime": null,
#             "second_max_nonoverlap_value": null,
#             "second_max_value": 0.066,
#             "secondary_exceedance_count": 1,
#             "seventy_fifth_percentile": 0.046,
#             "site_address": "NO. B'HAM,SOU R.R., 3009 28TH ST. NO.",
#             "site_number": "0023",
#             "standard_deviation": 0.011771,
#             "state": "Alabama",
#             "state_code": "01",
#             "tenth_percentile": 0.021,
#             "third_max_datetime": "2017-04-13 10:00",
#             "third_max_value": 0.062,
#             "units_of_measure": "Parts per million",
#             "valid_day_count": 304,
#             "validity_indicator": "Y",
#             "year": 2017
#         },
#         {
#             "arithmetic_mean": 0.044493,
#             "cbsa": "Mobile, AL",
#             "cbsa_code": "33660",
#             "certification_indicator": "Certified",
#             "city": "Chickasaw",
#             "county": "Mobile",
#             "county_code": "097",
#             "date_of_last_change": "2018-07-19",
#             "datum": "NAD83",
#             "event_type": "No Events",
#             "exceptional_data_count": 0,
#             "fiftieth_percentile": 0.044,
#             "first_max_datetime": "2017-05-02 13:00",
#             "first_max_n_o_datetime": null,
#             "first_max_nonoverlap_value": null,
#             "first_max_value": 0.083,
#             "fourth_max_datetime": "2017-07-22 12:00",
#             "fourth_max_value": 0.072,
#             "latitude": 30.770181,
#             "local_site_name": "CHICKASAW",
#             "longitude": -88.087761,
#             "method": "INSTRUMENTAL - ULTRA VIOLET ABSORPTION",
#             "metric_used": "Daily maxima of observed hourly values (between 9:00 AM and 8:00 PM)",
#             "ninetieth_percentile": 0.062,
#             "ninety_eighth_percentile": 0.071,
#             "ninety_fifth_percentile": 0.065,
#             "ninety_ninth_percentile": 0.077,
#             "null_observation_count": 579,
#             "observation_count": 5301,
#             "observation_percent": 93.0,
#             "parameter": "Ozone",
#             "parameter_code": "44201",
#             "poc": 1,
#             "pollutant_standard": "Ozone 1-hour 1979",
#             "primary_exceedance_count": 0,
#             "required_day_count": 245,
#             "sample_duration": "1 HOUR",
#             "second_max_datetime": "2017-05-09 14:00",
#             "second_max_n_o_datetime": null,
#             "second_max_nonoverlap_value": null,
#             "second_max_value": 0.082,
#             "secondary_exceedance_count": 0,
#             "seventy_fifth_percentile": 0.053,
#             "site_address": "Iroquois and Azalea, CHICKASAW, MOBILE CO.,  ALABAMA",
#             "site_number": "0003",
#             "standard_deviation": 0.012462,
#             "state": "Alabama",
#             "state_code": "01",
#             "tenth_percentile": 0.028,
#             "third_max_datetime": "2017-05-10 13:00",
#             "third_max_value": 0.077,
#             "units_of_measure": "Parts per million",
#             "valid_day_count": 229,
#             "validity_indicator": "Y",
#             "year": 2017
#         },
#         {
#             "arithmetic_mean": 0.039157,
#             "cbsa": "Mobile, AL",
#             "cbsa_code": "33660",
#             "certification_indicator": "Certified",
#             "city": "Chickasaw",
#             "county": "Mobile",
#             "county_code": "097",
#             "date_of_last_change": "2018-07-19",
#             "datum": "NAD83",
#             "event_type": "No Events",
#             "exceptional_data_count": 0,
#             "fiftieth_percentile": 0.039,
#             "first_max_datetime": "2017-05-02 09:00",
#             "first_max_n_o_datetime": null,
#             "first_max_nonoverlap_value": null,
#             "first_max_value": 0.071,
#             "fourth_max_datetime": "2017-05-08 09:00",
#             "fourth_max_value": 0.065,
#             "latitude": 30.770181,
#             "local_site_name": "CHICKASAW",
#             "longitude": -88.087761,
#             "method": null,
#             "metric_used": "Daily maximum of 8 hour running average of observed hourly values",
#             "ninetieth_percentile": 0.054,
#             "ninety_eighth_percentile": 0.061,
#             "ninety_fifth_percentile": 0.058,
#             "ninety_ninth_percentile": 0.069,
#             "null_observation_count": 0,
#             "observation_count": 5542,
#             "observation_percent": 93.0,
#             "parameter": "Ozone",
#             "parameter_code": "44201",
#             "poc": 1,
#             "pollutant_standard": "Ozone 8-Hour 1997",
#             "primary_exceedance_count": 0,
#             "required_day_count": 245,
#             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#             "second_max_datetime": "2017-05-09 09:00",
#             "second_max_n_o_datetime": null,
#             "second_max_nonoverlap_value": null,
#             "second_max_value": 0.07,
#             "secondary_exceedance_count": 0,
#             "seventy_fifth_percentile": 0.048,
#             "site_address": "Iroquois and Azalea, CHICKASAW, MOBILE CO.,  ALABAMA",
#             "site_number": "0003",
#             "standard_deviation": 0.011482,
#             "state": "Alabama",
#             "state_code": "01",
#             "tenth_percentile": 0.023,
#             "third_max_datetime": "2017-05-10 09:00",
#             "third_max_value": 0.069,
#             "units_of_measure": "Parts per million",
#             "valid_day_count": 229,
#             "validity_indicator": "Y",
#             "year": 2017
#         },
#         {
#             "arithmetic_mean": 0.039157,
#             "cbsa": "Mobile, AL",
#             "cbsa_code": "33660",
#             "certification_indicator": "Certified",
#             "city": "Chickasaw",
#             "county": "Mobile",
#             "county_code": "097",
#             "date_of_last_change": "2018-07-19",
#             "datum": "NAD83",
#             "event_type": "No Events",
#             "exceptional_data_count": 0,
#             "fiftieth_percentile": 0.039,
#             "first_max_datetime": "2017-05-02 09:00",
#             "first_max_n_o_datetime": null,
#             "first_max_nonoverlap_value": null,
#             "first_max_value": 0.071,
#             "fourth_max_datetime": "2017-05-08 09:00",
#             "fourth_max_value": 0.065,
#             "latitude": 30.770181,
#             "local_site_name": "CHICKASAW",
#             "longitude": -88.087761,
#             "method": null,
#             "metric_used": "Daily maximum of 8 hour running average of observed hourly values",
#             "ninetieth_percentile": 0.054,
#             "ninety_eighth_percentile": 0.061,
#             "ninety_fifth_percentile": 0.058,
#             "ninety_ninth_percentile": 0.069,
#             "null_observation_count": 0,
#             "observation_count": 5542,
#             "observation_percent": 93.0,
#             "parameter": "Ozone",
#             "parameter_code": "44201",
#             "poc": 1,
#             "pollutant_standard": "Ozone 8-Hour 2008",
#             "primary_exceedance_count": 0,
#             "required_day_count": 245,
#             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#             "second_max_datetime": "2017-05-09 09:00",
#             "second_max_n_o_datetime": null,
#             "second_max_nonoverlap_value": null,
#             "second_max_value": 0.07,
#             "secondary_exceedance_count": 0,
#             "seventy_fifth_percentile": 0.048,
#             "site_address": "Iroquois and Azalea, CHICKASAW, MOBILE CO.,  ALABAMA",
#             "site_number": "0003",
#             "standard_deviation": 0.011482,
#             "state": "Alabama",
#             "state_code": "01",
#             "tenth_percentile": 0.023,
#             "third_max_datetime": "2017-05-10 09:00",
#             "third_max_value": 0.069,
#             "units_of_measure": "Parts per million",
#             "valid_day_count": 229,
#             "validity_indicator": "Y",
#             "year": 2017
#         },
#         {
#             "arithmetic_mean": 0.039111,
#             "cbsa": "Mobile, AL",
#             "cbsa_code": "33660",
#             "certification_indicator": "Certified",
#             "city": "Chickasaw",
#             "county": "Mobile",
#             "county_code": "097",
#             "date_of_last_change": "2018-07-19",
#             "datum": "NAD83",
#             "event_type": "No Events",
#             "exceptional_data_count": 0,
#             "fiftieth_percentile": 0.039,
#             "first_max_datetime": "2017-05-02 09:00",
#             "first_max_n_o_datetime": null,
#             "first_max_nonoverlap_value": null,
#             "first_max_value": 0.071,
#             "fourth_max_datetime": "2017-05-08 09:00",
#             "fourth_max_value": 0.065,
#             "latitude": 30.770181,
#             "local_site_name": "CHICKASAW",
#             "longitude": -88.087761,
#             "method": null,
#             "metric_used": "Daily maximum of 8-hour running average",
#             "ninetieth_percentile": 0.054,
#             "ninety_eighth_percentile": 0.061,
#             "ninety_fifth_percentile": 0.058,
#             "ninety_ninth_percentile": 0.069,
#             "null_observation_count": 0,
#             "observation_count": 3922,
#             "observation_percent": 92.0,
#             "parameter": "Ozone",
#             "parameter_code": "44201",
#             "poc": 1,
#             "pollutant_standard": "Ozone 8-hour 2015",
#             "primary_exceedance_count": 1,
#             "required_day_count": 245,
#             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#             "second_max_datetime": "2017-05-09 09:00",
#             "second_max_n_o_datetime": null,
#             "second_max_nonoverlap_value": null,
#             "second_max_value": 0.07,
#             "secondary_exceedance_count": 1,
#             "seventy_fifth_percentile": 0.048,
#             "site_address": "Iroquois and Azalea, CHICKASAW, MOBILE CO.,  ALABAMA",
#             "site_number": "0003",
#             "standard_deviation": 0.01152,
#             "state": "Alabama",
#             "state_code": "01",
#             "tenth_percentile": 0.024,
#             "third_max_datetime": "2017-05-10 09:00",
#             "third_max_value": 0.069,
#             "units_of_measure": "Parts per million",
#             "valid_day_count": 226,
#             "validity_indicator": "Y",
#             "year": 2017
#         },
#         {
#             "arithmetic_mean": 0.04628,
#             "cbsa": "Fort Payne, AL",
#             "cbsa_code": "22840",
#             "certification_indicator": "Certified",
#             "city": "Crossville",
#             "county": "DeKalb",
#             "county_code": "049",
#             "date_of_last_change": "2018-07-20",
#             "datum": "NAD83",
#             "event_type": "No Events",
#             "exceptional_data_count": 0,
#             "fiftieth_percentile": 0.048,
#             "first_max_datetime": "2017-05-26 15:00",
#             "first_max_n_o_datetime": null,
#             "first_max_nonoverlap_value": null,
#             "first_max_value": 0.071,
#             "fourth_max_datetime": "2017-04-13 14:00",
#             "fourth_max_value": 0.063,
#             "latitude": 34.289001,
#             "local_site_name": "Sand Mountain",
#             "longitude": -85.970065,
#             "method": "INSTRUMENTAL - ULTRA VIOLET",
#             "metric_used": "Daily maxima of observed hourly values (between 9:00 AM and 8:00 PM)",
#             "ninetieth_percentile": 0.058,
#             "ninety_eighth_percentile": 0.062,
#             "ninety_fifth_percentile": 0.06,
#             "ninety_ninth_percentile": 0.064,
#             "null_observation_count": 586,
#             "observation_count": 8174,
#             "observation_percent": 96.0,
#             "parameter": "Ozone",
#             "parameter_code": "44201",
#             "poc": 1,
#             "pollutant_standard": "Ozone 1-hour 1979",
#             "primary_exceedance_count": 0,
#             "required_day_count": 245,
#             "sample_duration": "1 HOUR",
#             "second_max_datetime": "2017-05-15 16:00",
#             "second_max_n_o_datetime": null,
#             "second_max_nonoverlap_value": null,
#             "second_max_value": 0.064,
#             "secondary_exceedance_count": 0,
#             "seventy_fifth_percentile": 0.053,
#             "site_address": "Sand Mountain Alabama Agricultural Experiment Station, Crossville, AL 35962",
#             "site_number": "9991",
#             "standard_deviation": 0.009399,
#             "state": "Alabama",
#             "state_code": "01",
#             "tenth_percentile": 0.041,
#             "third_max_datetime": "2017-09-28 13:00",
#             "third_max_value": 0.064,
#             "units_of_measure": "Parts per million",
#             "valid_day_count": 236,
#             "validity_indicator": "Y",
#             "year": 2017
#         },
#         {
#             "arithmetic_mean": 0.042424,
#             "cbsa": "Fort Payne, AL",
#             "cbsa_code": "22840",
#             "certification_indicator": "Certified",
#             "city": "Crossville",
#             "county": "DeKalb",
#             "county_code": "049",
#             "date_of_last_change": "2018-07-20",
#             "datum": "NAD83",
#             "event_type": "No Events",
#             "exceptional_data_count": 0,
#             "fiftieth_percentile": 0.045,
#             "first_max_datetime": "2017-05-26 11:00",
#             "first_max_n_o_datetime": null,
#             "first_max_nonoverlap_value": null,
#             "first_max_value": 0.064,
#             "fourth_max_datetime": "2017-05-16 08:00",
#             "fourth_max_value": 0.058,
#             "latitude": 34.289001,
#             "local_site_name": "Sand Mountain",
#             "longitude": -85.970065,
#             "method": null,
#             "metric_used": "Daily maximum of 8 hour running average of observed hourly values",
#             "ninetieth_percentile": 0.053,
#             "ninety_eighth_percentile": 0.057,
#             "ninety_fifth_percentile": 0.055,
#             "ninety_ninth_percentile": 0.059,
#             "null_observation_count": 0,
#             "observation_count": 8546,
#             "observation_percent": 96.0,
#             "parameter": "Ozone",
#             "parameter_code": "44201",
#             "poc": 1,
#             "pollutant_standard": "Ozone 8-Hour 1997",
#             "primary_exceedance_count": 0,
#             "required_day_count": 245,
#             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#             "second_max_datetime": "2017-04-13 10:00",
#             "second_max_n_o_datetime": null,
#             "second_max_nonoverlap_value": null,
#             "second_max_value": 0.061,
#             "secondary_exceedance_count": 0,
#             "seventy_fifth_percentile": 0.049,
#             "site_address": "Sand Mountain Alabama Agricultural Experiment Station, Crossville, AL 35962",
#             "site_number": "9991",
#             "standard_deviation": 0.009271,
#             "state": "Alabama",
#             "state_code": "01",
#             "tenth_percentile": 0.037,
#             "third_max_datetime": "2017-04-10 09:00",
#             "third_max_value": 0.059,
#             "units_of_measure": "Parts per million",
#             "valid_day_count": 236,
#             "validity_indicator": "Y",
#             "year": 2017
#         },
#         {
#             "arithmetic_mean": 0.042424,
#             "cbsa": "Fort Payne, AL",
#             "cbsa_code": "22840",
#             "certification_indicator": "Certified",
#             "city": "Crossville",
#             "county": "DeKalb",
#             "county_code": "049",
#             "date_of_last_change": "2018-07-20",
#             "datum": "NAD83",
#             "event_type": "No Events",
#             "exceptional_data_count": 0,
#             "fiftieth_percentile": 0.045,
#             "first_max_datetime": "2017-05-26 11:00",
#             "first_max_n_o_datetime": null,
#             "first_max_nonoverlap_value": null,
#             "first_max_value": 0.064,
#             "fourth_max_datetime": "2017-05-16 08:00",
#             "fourth_max_value": 0.058,
#             "latitude": 34.289001,
#             "local_site_name": "Sand Mountain",
#             "longitude": -85.970065,
#             "method": null,
#             "metric_used": "Daily maximum of 8 hour running average of observed hourly values",
#             "ninetieth_percentile": 0.053,
#             "ninety_eighth_percentile": 0.057,
#             "ninety_fifth_percentile": 0.055,
#             "ninety_ninth_percentile": 0.059,
#             "null_observation_count": 0,
#             "observation_count": 8546,
#             "observation_percent": 96.0,
#             "parameter": "Ozone",
#             "parameter_code": "44201",
#             "poc": 1,
#             "pollutant_standard": "Ozone 8-Hour 2008",
#             "primary_exceedance_count": 0,
#             "required_day_count": 245,
#             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#             "second_max_datetime": "2017-04-13 10:00",
#             "second_max_n_o_datetime": null,
#             "second_max_nonoverlap_value": null,
#             "second_max_value": 0.061,
#             "secondary_exceedance_count": 0,
#             "seventy_fifth_percentile": 0.049,
#             "site_address": "Sand Mountain Alabama Agricultural Experiment Station, Crossville, AL 35962",
#             "site_number": "9991",
#             "standard_deviation": 0.009271,
#             "state": "Alabama",
#             "state_code": "01",
#             "tenth_percentile": 0.037,
#             "third_max_datetime": "2017-04-10 09:00",
#             "third_max_value": 0.059,
#             "units_of_measure": "Parts per million",
#             "valid_day_count": 236,
#             "validity_indicator": "Y",
#             "year": 2017
#         },
#         {
#             "arithmetic_mean": 0.042339,
#             "cbsa": "Fort Payne, AL",
#             "cbsa_code": "22840",
#             "certification_indicator": "Certified",
#             "city": "Crossville",
#             "county": "DeKalb",
#             "county_code": "049",
#             "date_of_last_change": "2018-07-20",
#             "datum": "NAD83",
#             "event_type": "No Events",
#             "exceptional_data_count": 0,
#             "fiftieth_percentile": 0.045,
#             "first_max_datetime": "2017-05-26 11:00",
#             "first_max_n_o_datetime": null,
#             "first_max_nonoverlap_value": null,
#             "first_max_value": 0.064,
#             "fourth_max_datetime": "2017-05-16 08:00",
#             "fourth_max_value": 0.058,
#             "latitude": 34.289001,
#             "local_site_name": "Sand Mountain",
#             "longitude": -85.970065,
#             "method": null,
#             "metric_used": "Daily maximum of 8-hour running average",
#             "ninetieth_percentile": 0.053,
#             "ninety_eighth_percentile": 0.057,
#             "ninety_fifth_percentile": 0.055,
#             "ninety_ninth_percentile": 0.059,
#             "null_observation_count": 0,
#             "observation_count": 6056,
#             "observation_percent": 96.0,
#             "parameter": "Ozone",
#             "parameter_code": "44201",
#             "poc": 1,
#             "pollutant_standard": "Ozone 8-hour 2015",
#             "primary_exceedance_count": 0,
#             "required_day_count": 245,
#             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#             "second_max_datetime": "2017-04-13 10:00",
#             "second_max_n_o_datetime": null,
#             "second_max_nonoverlap_value": null,
#             "second_max_value": 0.061,
#             "secondary_exceedance_count": 0,
#             "seventy_fifth_percentile": 0.049,
#             "site_address": "Sand Mountain Alabama Agricultural Experiment Station, Crossville, AL 35962",
#             "site_number": "9991",
#             "standard_deviation": 0.009338,
#             "state": "Alabama",
#             "state_code": "01",
#             "tenth_percentile": 0.037,
#             "third_max_datetime": "2017-04-10 09:00",
#             "third_max_value": 0.059,
#             "units_of_measure": "Parts per million",
#             "valid_day_count": 236,
#             "validity_indicator": "Y",
#             "year": 2017
#         },
#         {
#             "arithmetic_mean": 0.046169,
#             "cbsa": "Decatur, AL",
#             "cbsa_code": "19460",
#             "certification_indicator": "Certified",
#             "city": "Decatur",
#             "county": "Morgan",
#             "county_code": "103",
#             "date_of_last_change": "2018-07-19",
#             "datum": "NAD83",
#             "event_type": "No Events",
#             "exceptional_data_count": 0,
#             "fiftieth_percentile": 0.048,
#             "first_max_datetime": "2017-04-13 15:00",
#             "first_max_n_o_datetime": null,
#             "first_max_nonoverlap_value": null,
#             "first_max_value": 0.07,
#             "fourth_max_datetime": "2017-03-20 13:00",
#             "fourth_max_value": 0.065,
#             "latitude": 34.530717,
#             "local_site_name": "DECATUR, Alabama",
#             "longitude": -86.967536,
#             "method": "INSTRUMENTAL - ULTRA VIOLET",
#             "metric_used": "Daily maxima of observed hourly values (between 9:00 AM and 8:00 PM)",
#             "ninetieth_percentile": 0.06,
#             "ninety_eighth_percentile": 0.065,
#             "ninety_fifth_percentile": 0.062,
#             "ninety_ninth_percentile": 0.066,
#             "null_observation_count": 481,
#             "observation_count": 5399,
#             "observation_percent": 96.0,
#             "parameter": "Ozone",
#             "parameter_code": "44201",
#             "poc": 1,
#             "pollutant_standard": "Ozone 1-hour 1979",
#             "primary_exceedance_count": 0,
#             "required_day_count": 245,
#             "sample_duration": "1 HOUR",
#             "second_max_datetime": "2017-05-08 13:00",
#             "second_max_n_o_datetime": null,
#             "second_max_nonoverlap_value": null,
#             "second_max_value": 0.069,
#             "secondary_exceedance_count": 0,
#             "seventy_fifth_percentile": 0.053,
#             "site_address": "P.O. BOX 2224 WALLACE DEVELOPMENT CENTER. DECATUR, ALABAMA",
#             "site_number": "0011",
#             "standard_deviation": 0.010715,
#             "state": "Alabama",
#             "state_code": "01",
#             "tenth_percentile": 0.03,
#             "third_max_datetime": "2017-04-14 13:00",
#             "third_max_value": 0.066,
#             "units_of_measure": "Parts per million",
#             "valid_day_count": 236,
#             "validity_indicator": "Y",
#             "year": 2017
#         },
#         {
#             "arithmetic_mean": 0.041528,
#             "cbsa": "Decatur, AL",
#             "cbsa_code": "19460",
#             "certification_indicator": "Certified",
#             "city": "Decatur",
#             "county": "Morgan",
#             "county_code": "103",
#             "date_of_last_change": "2018-07-19",
#             "datum": "NAD83",
#             "event_type": "No Events",
#             "exceptional_data_count": 0,
#             "fiftieth_percentile": 0.044,
#             "first_max_datetime": "2017-04-13 10:00",
#             "first_max_n_o_datetime": null,
#             "first_max_nonoverlap_value": null,
#             "first_max_value": 0.064,
#             "fourth_max_datetime": "2017-04-09 10:00",
#             "fourth_max_value": 0.06,
#             "latitude": 34.530717,
#             "local_site_name": "DECATUR, Alabama",
#             "longitude": -86.967536,
#             "method": null,
#             "metric_used": "Daily maximum of 8 hour running average of observed hourly values",
#             "ninetieth_percentile": 0.053,
#             "ninety_eighth_percentile": 0.059,
#             "ninety_fifth_percentile": 0.057,
#             "ninety_ninth_percentile": 0.061,
#             "null_observation_count": 0,
#             "observation_count": 5623,
#             "observation_percent": 95.0,
#             "parameter": "Ozone",
#             "parameter_code": "44201",
#             "poc": 1,
#             "pollutant_standard": "Ozone 8-Hour 1997",
#             "primary_exceedance_count": 0,
#             "required_day_count": 245,
#             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#             "second_max_datetime": "2017-05-08 09:00",
#             "second_max_n_o_datetime": null,
#             "second_max_nonoverlap_value": null,
#             "second_max_value": 0.062,
#             "secondary_exceedance_count": 0,
#             "seventy_fifth_percentile": 0.049,
#             "site_address": "P.O. BOX 2224 WALLACE DEVELOPMENT CENTER. DECATUR, ALABAMA",
#             "site_number": "0011",
#             "standard_deviation": 0.010294,
#             "state": "Alabama",
#             "state_code": "01",
#             "tenth_percentile": 0.026,
#             "third_max_datetime": "2017-04-14 10:00",
#             "third_max_value": 0.061,
#             "units_of_measure": "Parts per million",
#             "valid_day_count": 233,
#             "validity_indicator": "Y",
#             "year": 2017
#         },
#         {
#             "arithmetic_mean": 0.041528,
#             "cbsa": "Decatur, AL",
#             "cbsa_code": "19460",
#             "certification_indicator": "Certified",
#             "city": "Decatur",
#             "county": "Morgan",
#             "county_code": "103",
#             "date_of_last_change": "2018-07-19",
#             "datum": "NAD83",
#             "event_type": "No Events",
#             "exceptional_data_count": 0,
#             "fiftieth_percentile": 0.044,
#             "first_max_datetime": "2017-04-13 10:00",
#             "first_max_n_o_datetime": null,
#             "first_max_nonoverlap_value": null,
#             "first_max_value": 0.064,
#             "fourth_max_datetime": "2017-04-09 10:00",
#             "fourth_max_value": 0.06,
#             "latitude": 34.530717,
#             "local_site_name": "DECATUR, Alabama",
#             "longitude": -86.967536,
#             "method": null,
#             "metric_used": "Daily maximum of 8 hour running average of observed hourly values",
#             "ninetieth_percentile": 0.053,
#             "ninety_eighth_percentile": 0.059,
#             "ninety_fifth_percentile": 0.057,
#             "ninety_ninth_percentile": 0.061,
#             "null_observation_count": 0,
#             "observation_count": 5623,
#             "observation_percent": 95.0,
#             "parameter": "Ozone",
#             "parameter_code": "44201",
#             "poc": 1,
#             "pollutant_standard": "Ozone 8-Hour 2008",
#             "primary_exceedance_count": 0,
#             "required_day_count": 245,
#             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#             "second_max_datetime": "2017-05-08 09:00",
#             "second_max_n_o_datetime": null,
#             "second_max_nonoverlap_value": null,
#             "second_max_value": 0.062,
#             "secondary_exceedance_count": 0,
#             "seventy_fifth_percentile": 0.049,
#             "site_address": "P.O. BOX 2224 WALLACE DEVELOPMENT CENTER. DECATUR, ALABAMA",
#             "site_number": "0011",
#             "standard_deviation": 0.010294,
#             "state": "Alabama",
#             "state_code": "01",
#             "tenth_percentile": 0.026,
#             "third_max_datetime": "2017-04-14 10:00",
#             "third_max_value": 0.061,
#             "units_of_measure": "Parts per million",
#             "valid_day_count": 233,
#             "validity_indicator": "Y",
#             "year": 2017
#         },
#         {
#             "arithmetic_mean": 0.041502,
#             "cbsa": "Decatur, AL",
#             "cbsa_code": "19460",
#             "certification_indicator": "Certified",
#             "city": "Decatur",
#             "county": "Morgan",
#             "county_code": "103",
#             "date_of_last_change": "2018-07-19",
#             "datum": "NAD83",
#             "event_type": "No Events",
#             "exceptional_data_count": 0,
#             "fiftieth_percentile": 0.044,
#             "first_max_datetime": "2017-04-13 10:00",
#             "first_max_n_o_datetime": null,
#             "first_max_nonoverlap_value": null,
#             "first_max_value": 0.064,
#             "fourth_max_datetime": "2017-04-09 10:00",
#             "fourth_max_value": 0.06,
#             "latitude": 34.530717,
#             "local_site_name": "DECATUR, Alabama",
#             "longitude": -86.967536,
#             "method": null,
#             "metric_used": "Daily maximum of 8-hour running average",
#             "ninetieth_percentile": 0.053,
#             "ninety_eighth_percentile": 0.059,
#             "ninety_fifth_percentile": 0.057,
#             "ninety_ninth_percentile": 0.061,
#             "null_observation_count": 0,
#             "observation_count": 3981,
#             "observation_percent": 94.0,
#             "parameter": "Ozone",
#             "parameter_code": "44201",
#             "poc": 1,
#             "pollutant_standard": "Ozone 8-hour 2015",
#             "primary_exceedance_count": 0,
#             "required_day_count": 245,
#             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#             "second_max_datetime": "2017-05-08 09:00",
#             "second_max_n_o_datetime": null,
#             "second_max_nonoverlap_value": null,
#             "second_max_value": 0.062,
#             "secondary_exceedance_count": 0,
#             "seventy_fifth_percentile": 0.049,
#             "site_address": "P.O. BOX 2224 WALLACE DEVELOPMENT CENTER. DECATUR, ALABAMA",
#             "site_number": "0011",
#             "standard_deviation": 0.010274,
#             "state": "Alabama",
#             "state_code": "01",
#             "tenth_percentile": 0.026,
#             "third_max_datetime": "2017-04-14 10:00",
#             "third_max_value": 0.061,
#             "units_of_measure": "Parts per million",
#             "valid_day_count": 231,
#             "validity_indicator": "Y",
#             "year": 2017
#         },
#         {
#             "arithmetic_mean": 0.039228,
#             "cbsa": "Dothan, AL",
#             "cbsa_code": "20020",
#             "certification_indicator": "Certified",
#             "city": "Dothan",
#             "county": "Houston",
#             "county_code": "069",
#             "date_of_last_change": "2019-11-19",
#             "datum": "NAD83",
#             "event_type": "No Events",
#             "exceptional_data_count": 0,
#             "fiftieth_percentile": 0.04,
#             "first_max_datetime": "2017-05-10 10:00",
#             "first_max_n_o_datetime": null,
#             "first_max_nonoverlap_value": null,
#             "first_max_value": 0.06,
#             "fourth_max_datetime": "2017-05-15 15:00",
#             "fourth_max_value": 0.059,
#             "latitude": 31.188933,
#             "local_site_name": "DOTHAN",
#             "longitude": -85.423094,
#             "method": "INSTRUMENTAL - ULTRA VIOLET ABSORPTION",
#             "metric_used": "Daily maxima of observed hourly values (between 9:00 AM and 8:00 PM)",
#             "ninetieth_percentile": 0.053,
#             "ninety_eighth_percentile": 0.058,
#             "ninety_fifth_percentile": 0.055,
#             "ninety_ninth_percentile": 0.059,
#             "null_observation_count": 338,
#             "observation_count": 5542,
#             "observation_percent": 98.0,
#             "parameter": "Ozone",
#             "parameter_code": "44201",
#             "poc": 1,
#             "pollutant_standard": "Ozone 1-hour 1979",
#             "primary_exceedance_count": 0,
#             "required_day_count": 245,
#             "sample_duration": "1 HOUR",
#             "second_max_datetime": "2017-04-02 12:00",
#             "second_max_n_o_datetime": null,
#             "second_max_nonoverlap_value": null,
#             "second_max_value": 0.059,
#             "secondary_exceedance_count": 0,
#             "seventy_fifth_percentile": 0.047,
#             "site_address": "161 BUFORD LANE",
#             "site_number": "0004",
#             "standard_deviation": 0.010432,
#             "state": "Alabama",
#             "state_code": "01",
#             "tenth_percentile": 0.024,
#             "third_max_datetime": "2017-04-09 13:00",
#             "third_max_value": 0.059,
#             "units_of_measure": "Parts per million",
#             "valid_day_count": 241,
#             "validity_indicator": "Y",
#             "year": 2017
#         },
#         {
#             "arithmetic_mean": 0.035438,
#             "cbsa": "Dothan, AL",
#             "cbsa_code": "20020",
#             "certification_indicator": "Certified",
#             "city": "Dothan",
#             "county": "Houston",
#             "county_code": "069",
#             "date_of_last_change": "2019-11-19",
#             "datum": "NAD83",
#             "event_type": "No Events",
#             "exceptional_data_count": 0,
#             "fiftieth_percentile": 0.036,
#             "first_max_datetime": "2017-05-10 08:00",
#             "first_max_n_o_datetime": null,
#             "first_max_nonoverlap_value": null,
#             "first_max_value": 0.057,
#             "fourth_max_datetime": "2017-04-10 09:00",
#             "fourth_max_value": 0.055,
#             "latitude": 31.188933,
#             "local_site_name": "DOTHAN",
#             "longitude": -85.423094,
#             "method": null,
#             "metric_used": "Daily maximum of 8 hour running average of observed hourly values",
#             "ninetieth_percentile": 0.049,
#             "ninety_eighth_percentile": 0.055,
#             "ninety_fifth_percentile": 0.052,
#             "ninety_ninth_percentile": 0.055,
#             "null_observation_count": 0,
#             "observation_count": 5811,
#             "observation_percent": 98.0,
#             "parameter": "Ozone",
#             "parameter_code": "44201",
#             "poc": 1,
#             "pollutant_standard": "Ozone 8-Hour 1997",
#             "primary_exceedance_count": 0,
#             "required_day_count": 245,
#             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#             "second_max_datetime": "2017-04-09 08:00",
#             "second_max_n_o_datetime": null,
#             "second_max_nonoverlap_value": null,
#             "second_max_value": 0.056,
#             "secondary_exceedance_count": 0,
#             "seventy_fifth_percentile": 0.044,
#             "site_address": "161 BUFORD LANE",
#             "site_number": "0004",
#             "standard_deviation": 0.01048,
#             "state": "Alabama",
#             "state_code": "01",
#             "tenth_percentile": 0.021,
#             "third_max_datetime": "2017-04-02 09:00",
#             "third_max_value": 0.055,
#             "units_of_measure": "Parts per million",
#             "valid_day_count": 240,
#             "validity_indicator": "Y",
#             "year": 2017
#         },
#         {
#             "arithmetic_mean": 0.035438,
#             "cbsa": "Dothan, AL",
#             "cbsa_code": "20020",
#             "certification_indicator": "Certified",
#             "city": "Dothan",
#             "county": "Houston",
#             "county_code": "069",
#             "date_of_last_change": "2019-11-19",
#             "datum": "NAD83",
#             "event_type": "No Events",
#             "exceptional_data_count": 0,
#             "fiftieth_percentile": 0.036,
#             "first_max_datetime": "2017-05-10 08:00",
#             "first_max_n_o_datetime": null,
#             "first_max_nonoverlap_value": null,
#             "first_max_value": 0.057,
#             "fourth_max_datetime": "2017-04-10 09:00",
#             "fourth_max_value": 0.055,
#             "latitude": 31.188933,
#             "local_site_name": "DOTHAN",
#             "longitude": -85.423094,
#             "method": null,
#             "metric_used": "Daily maximum of 8 hour running average of observed hourly values",
#             "ninetieth_percentile": 0.049,
#             "ninety_eighth_percentile": 0.055,
#             "ninety_fifth_percentile": 0.052,
#             "ninety_ninth_percentile": 0.055,
#             "null_observation_count": 0,
#             "observation_count": 5811,
#             "observation_percent": 98.0,
#             "parameter": "Ozone",
#             "parameter_code": "44201",
#             "poc": 1,
#             "pollutant_standard": "Ozone 8-Hour 2008",
#             "primary_exceedance_count": 0,
#             "required_day_count": 245,
#             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#             "second_max_datetime": "2017-04-09 08:00",
#             "second_max_n_o_datetime": null,
#             "second_max_nonoverlap_value": null,
#             "second_max_value": 0.056,
#             "secondary_exceedance_count": 0,
#             "seventy_fifth_percentile": 0.044,
#             "site_address": "161 BUFORD LANE",
#             "site_number": "0004",
#             "standard_deviation": 0.01048,
#             "state": "Alabama",
#             "state_code": "01",
#             "tenth_percentile": 0.021,
#             "third_max_datetime": "2017-04-02 09:00",
#             "third_max_value": 0.055,
#             "units_of_measure": "Parts per million",
#             "valid_day_count": 240,
#             "validity_indicator": "Y",
#             "year": 2017
#         },
#         {
#             "arithmetic_mean": 0.035285,
#             "cbsa": "Dothan, AL",
#             "cbsa_code": "20020",
#             "certification_indicator": "Certified",
#             "city": "Dothan",
#             "county": "Houston",
#             "county_code": "069",
#             "date_of_last_change": "2019-11-19",
#             "datum": "NAD83",
#             "event_type": "No Events",
#             "exceptional_data_count": 0,
#             "fiftieth_percentile": 0.035,
#             "first_max_datetime": "2017-05-10 08:00",
#             "first_max_n_o_datetime": null,
#             "first_max_nonoverlap_value": null,
#             "first_max_value": 0.057,
#             "fourth_max_datetime": "2017-04-10 09:00",
#             "fourth_max_value": 0.055,
#             "latitude": 31.188933,
#             "local_site_name": "DOTHAN",
#             "longitude": -85.423094,
#             "method": null,
#             "metric_used": "Daily maximum of 8-hour running average",
#             "ninetieth_percentile": 0.049,
#             "ninety_eighth_percentile": 0.055,
#             "ninety_fifth_percentile": 0.052,
#             "ninety_ninth_percentile": 0.055,
#             "null_observation_count": 0,
#             "observation_count": 4111,
#             "observation_percent": 98.0,
#             "parameter": "Ozone",
#             "parameter_code": "44201",
#             "poc": 1,
#             "pollutant_standard": "Ozone 8-hour 2015",
#             "primary_exceedance_count": 0,
#             "required_day_count": 245,
#             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#             "second_max_datetime": "2017-04-09 08:00",
#             "second_max_n_o_datetime": null,
#             "second_max_nonoverlap_value": null,
#             "second_max_value": 0.056,
#             "secondary_exceedance_count": 0,
#             "seventy_fifth_percentile": 0.044,
#             "site_address": "161 BUFORD LANE",
#             "site_number": "0004",
#             "standard_deviation": 0.010507,
#             "state": "Alabama",
#             "state_code": "01",
#             "tenth_percentile": 0.021,
#             "third_max_datetime": "2017-04-02 09:00",
#             "third_max_value": 0.055,
#             "units_of_measure": "Parts per million",
#             "valid_day_count": 239,
#             "validity_indicator": "Y",
#             "year": 2017
#         },
#         {
#             "arithmetic_mean": 0.044753,
#             "cbsa": "Birmingham-Hoover, AL",
#             "cbsa_code": "13820",
#             "certification_indicator": "Certified",
#             "city": "Fairfield",
#             "county": "Jefferson",
#             "county_code": "073",
#             "date_of_last_change": "2018-10-17",
# ...
#             "local_site_name": "McAdory",
#             "longitude": -87.003611,
#             "method": null,
#             "metric_used": "Daily maximum of 8 hour running average of observed hourly values",
#             "ninetieth_percentile": 0.054,
#             "ninety_eighth_percentile": 0.062,
#             "ninety_fifth_percentile": 0.057,
#             "ninety_ninth_percentile": 0.063,
#             "null_observation_count": 0,
#             "observation_count": 5782,
#             "observation_percent": 96.0,
#             "parameter": "Ozone",
#             "parameter_code": "44201",
#             "poc": 1,
#             "pollutant_standard": "Ozone 8-Hour 1997",
#             "primary_exceedance_count": 0,
#             "required_day_count": 245,
#             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#             "second_max_datetime": "2017-07-10 10:00",
#             "second_max_n_o_datetime": null,
#             "second_max_nonoverlap_value": null,
#             "second_max_value": 0.067,
#             "secondary_exceedance_count": 0,
#             "seventy_fifth_percentile": 0.049,
#             "site_address": " ROUTE 8 MCADORY",
#             "site_number": "1005",
#             "standard_deviation": 0.011514,
#             "state": "Alabama",
#             "state_code": "01",
#             "tenth_percentile": 0.022,
#             "third_max_datetime": "2017-05-08 10:00",
#             "third_max_value": 0.063,
#             "units_of_measure": "Parts per million",
#             "valid_day_count": 235,
#             "validity_indicator": "Y",
#             "year": 2017
#         },
#         {
#             "arithmetic_mean": 0.03943,
#             "cbsa": "Birmingham-Hoover, AL",
#             "cbsa_code": "13820",
#             "certification_indicator": "Certified",
#             "city": null,
#             "county": "Jefferson",
#             "county_code": "073",
#             "date_of_last_change": "2018-07-20",
#             "datum": "WGS84",
#             "event_type": "No Events",
#             "exceptional_data_count": 0,
#             "fiftieth_percentile": 0.041,
#             "first_max_datetime": "2017-05-15 10:00",
#             "first_max_n_o_datetime": null,
#             "first_max_nonoverlap_value": null,
#             "first_max_value": 0.067,
#             "fourth_max_datetime": "2017-04-13 10:00",
#             "fourth_max_value": 0.062,
#             "latitude": 33.331111,
#             "local_site_name": "McAdory",
#             "longitude": -87.003611,
#             "method": null,
#             "metric_used": "Daily maximum of 8 hour running average of observed hourly values",
#             "ninetieth_percentile": 0.054,
#             "ninety_eighth_percentile": 0.062,
#             "ninety_fifth_percentile": 0.057,
#             "ninety_ninth_percentile": 0.063,
#             "null_observation_count": 0,
#             "observation_count": 5782,
#             "observation_percent": 96.0,
#             "parameter": "Ozone",
#             "parameter_code": "44201",
#             "poc": 1,
#             "pollutant_standard": "Ozone 8-Hour 2008",
#             "primary_exceedance_count": 0,
#             "required_day_count": 245,
#             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#             "second_max_datetime": "2017-07-10 10:00",
#             "second_max_n_o_datetime": null,
#             "second_max_nonoverlap_value": null,
#             "second_max_value": 0.067,
#             "secondary_exceedance_count": 0,
#             "seventy_fifth_percentile": 0.049,
#             "site_address": " ROUTE 8 MCADORY",
#             "site_number": "1005",
#             "standard_deviation": 0.011514,
#             "state": "Alabama",
#             "state_code": "01",
#             "tenth_percentile": 0.022,
#             "third_max_datetime": "2017-05-08 10:00",
#             "third_max_value": 0.063,
#             "units_of_measure": "Parts per million",
#             "valid_day_count": 235,
#             "validity_indicator": "Y",
#             "year": 2017
#         },
#         {
#             "arithmetic_mean": 0.039197,
#             "cbsa": "Birmingham-Hoover, AL",
#             "cbsa_code": "13820",
#             "certification_indicator": "Certified",
#             "city": null,
#             "county": "Jefferson",
#             "county_code": "073",
#             "date_of_last_change": "2018-07-20",
#             "datum": "WGS84",
#             "event_type": "No Events",
#             "exceptional_data_count": 0,
#             "fiftieth_percentile": 0.04,
#             "first_max_datetime": "2017-05-15 10:00",
#             "first_max_n_o_datetime": null,
#             "first_max_nonoverlap_value": null,
#             "first_max_value": 0.067,
#             "fourth_max_datetime": "2017-04-13 10:00",
#             "fourth_max_value": 0.062,
#             "latitude": 33.331111,
#             "local_site_name": "McAdory",
#             "longitude": -87.003611,
#             "method": null,
#             "metric_used": "Daily maximum of 8-hour running average",
#             "ninetieth_percentile": 0.054,
#             "ninety_eighth_percentile": 0.062,
#             "ninety_fifth_percentile": 0.057,
#             "ninety_ninth_percentile": 0.063,
#             "null_observation_count": 0,
#             "observation_count": 4154,
#             "observation_percent": 100.0,
#             "parameter": "Ozone",
#             "parameter_code": "44201",
#             "poc": 1,
#             "pollutant_standard": "Ozone 8-hour 2015",
#             "primary_exceedance_count": 0,
#             "required_day_count": 245,
#             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#             "second_max_datetime": "2017-07-10 10:00",
#             "second_max_n_o_datetime": null,
#             "second_max_nonoverlap_value": null,
#             "second_max_value": 0.067,
#             "secondary_exceedance_count": 0,
#             "seventy_fifth_percentile": 0.048,
#             "site_address": " ROUTE 8 MCADORY",
#             "site_number": "1005",
#             "standard_deviation": 0.011609,
#             "state": "Alabama",
#             "state_code": "01",
#             "tenth_percentile": 0.022,
#             "third_max_datetime": "2017-05-08 10:00",
#             "third_max_value": 0.063,
#             "units_of_measure": "Parts per million",
#             "valid_day_count": 244,
#             "validity_indicator": "Y",
#             "year": 2017
#         },
#         {
#             "arithmetic_mean": 0.045971,
#             "cbsa": "Birmingham-Hoover, AL",
#             "cbsa_code": "13820",
#             "certification_indicator": "Certified",
#             "city": null,
#             "county": "Jefferson",
#             "county_code": "073",
#             "date_of_last_change": "2018-07-20",
#             "datum": "WGS84",
#             "event_type": "No Events",
#             "exceptional_data_count": 0,
#             "fiftieth_percentile": 0.047,
#             "first_max_datetime": "2017-05-15 16:00",
#             "first_max_n_o_datetime": null,
#             "first_max_nonoverlap_value": null,
#             "first_max_value": 0.086,
#             "fourth_max_datetime": "2017-08-22 12:00",
#             "fourth_max_value": 0.07,
#             "latitude": 33.801667,
#             "local_site_name": "Corner",
#             "longitude": -86.9425,
#             "method": "INSTRUMENTAL - ULTRA VIOLET ABSORPTION",
#             "metric_used": "Daily maxima of observed hourly values (between 9:00 AM and 8:00 PM)",
#             "ninetieth_percentile": 0.06,
#             "ninety_eighth_percentile": 0.069,
#             "ninety_fifth_percentile": 0.065,
#             "ninety_ninth_percentile": 0.07,
#             "null_observation_count": 332,
#             "observation_count": 5548,
#             "observation_percent": 100.0,
#             "parameter": "Ozone",
#             "parameter_code": "44201",
#             "poc": 1,
#             "pollutant_standard": "Ozone 1-hour 1979",
#             "primary_exceedance_count": 0,
#             "required_day_count": 245,
#             "sample_duration": "1 HOUR",
#             "second_max_datetime": "2017-06-09 13:00",
#             "second_max_n_o_datetime": null,
#             "second_max_nonoverlap_value": null,
#             "second_max_value": 0.074,
#             "secondary_exceedance_count": 0,
#             "seventy_fifth_percentile": 0.053,
#             "site_address": "10005 CORNER SCHOOL ROAD",
#             "site_number": "5003",
#             "standard_deviation": 0.011264,
#             "state": "Alabama",
#             "state_code": "01",
#             "tenth_percentile": 0.031,
#             "third_max_datetime": "2017-05-03 11:00",
#             "third_max_value": 0.07,
#             "units_of_measure": "Parts per million",
#             "valid_day_count": 245,
#             "validity_indicator": "Y",
#             "year": 2017
#         },
#         {
#             "arithmetic_mean": 0.041225,
#             "cbsa": "Birmingham-Hoover, AL",
#             "cbsa_code": "13820",
#             "certification_indicator": "Certified",
#             "city": null,
#             "county": "Jefferson",
#             "county_code": "073",
#             "date_of_last_change": "2018-07-20",
#             "datum": "WGS84",
#             "event_type": "No Events",
#             "exceptional_data_count": 0,
#             "fiftieth_percentile": 0.043,
#             "first_max_datetime": "2017-06-09 10:00",
#             "first_max_n_o_datetime": null,
#             "first_max_nonoverlap_value": null,
#             "first_max_value": 0.066,
#             "fourth_max_datetime": "2017-04-13 10:00",
#             "fourth_max_value": 0.061,
#             "latitude": 33.801667,
#             "local_site_name": "Corner",
#             "longitude": -86.9425,
#             "method": null,
#             "metric_used": "Daily maximum of 8 hour running average of observed hourly values",
#             "ninetieth_percentile": 0.054,
#             "ninety_eighth_percentile": 0.061,
#             "ninety_fifth_percentile": 0.058,
#             "ninety_ninth_percentile": 0.061,
#             "null_observation_count": 0,
#             "observation_count": 5796,
#             "observation_percent": 98.0,
#             "parameter": "Ozone",
#             "parameter_code": "44201",
#             "poc": 1,
#             "pollutant_standard": "Ozone 8-Hour 1997",
#             "primary_exceedance_count": 0,
#             "required_day_count": 245,
#             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#             "second_max_datetime": "2017-05-15 10:00",
#             "second_max_n_o_datetime": null,
#             "second_max_nonoverlap_value": null,
#             "second_max_value": 0.065,
#             "secondary_exceedance_count": 0,
#             "seventy_fifth_percentile": 0.049,
#             "site_address": "10005 CORNER SCHOOL ROAD",
#             "site_number": "5003",
#             "standard_deviation": 0.010505,
#             "state": "Alabama",
#             "state_code": "01",
#             "tenth_percentile": 0.026,
#             "third_max_datetime": "2017-03-23 11:00",
#             "third_max_value": 0.061,
#             "units_of_measure": "Parts per million",
#             "valid_day_count": 240,
#             "validity_indicator": "Y",
#             "year": 2017
#         },
#         {
#             "arithmetic_mean": 0.041225,
#             "cbsa": "Birmingham-Hoover, AL",
#             "cbsa_code": "13820",
#             "certification_indicator": "Certified",
#             "city": null,
#             "county": "Jefferson",
#             "county_code": "073",
#             "date_of_last_change": "2018-07-20",
#             "datum": "WGS84",
#             "event_type": "No Events",
#             "exceptional_data_count": 0,
#             "fiftieth_percentile": 0.043,
#             "first_max_datetime": "2017-06-09 10:00",
#             "first_max_n_o_datetime": null,
#             "first_max_nonoverlap_value": null,
#             "first_max_value": 0.066,
#             "fourth_max_datetime": "2017-04-13 10:00",
#             "fourth_max_value": 0.061,
#             "latitude": 33.801667,
#             "local_site_name": "Corner",
#             "longitude": -86.9425,
#             "method": null,
#             "metric_used": "Daily maximum of 8 hour running average of observed hourly values",
#             "ninetieth_percentile": 0.054,
#             "ninety_eighth_percentile": 0.061,
#             "ninety_fifth_percentile": 0.058,
#             "ninety_ninth_percentile": 0.061,
#             "null_observation_count": 0,
#             "observation_count": 5796,
#             "observation_percent": 98.0,
#             "parameter": "Ozone",
#             "parameter_code": "44201",
#             "poc": 1,
#             "pollutant_standard": "Ozone 8-Hour 2008",
#             "primary_exceedance_count": 0,
#             "required_day_count": 245,
#             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#             "second_max_datetime": "2017-05-15 10:00",
#             "second_max_n_o_datetime": null,
#             "second_max_nonoverlap_value": null,
#             "second_max_value": 0.065,
#             "secondary_exceedance_count": 0,
#             "seventy_fifth_percentile": 0.049,
#             "site_address": "10005 CORNER SCHOOL ROAD",
#             "site_number": "5003",
#             "standard_deviation": 0.010505,
#             "state": "Alabama",
#             "state_code": "01",
#             "tenth_percentile": 0.026,
#             "third_max_datetime": "2017-03-23 11:00",
#             "third_max_value": 0.061,
#             "units_of_measure": "Parts per million",
#             "valid_day_count": 240,
#             "validity_indicator": "Y",
#             "year": 2017
#         },
#         {
#             "arithmetic_mean": 0.040988,
#             "cbsa": "Birmingham-Hoover, AL",
#             "cbsa_code": "13820",
#             "certification_indicator": "Certified",
#             "city": null,
#             "county": "Jefferson",
#             "county_code": "073",
#             "date_of_last_change": "2018-07-20",
#             "datum": "WGS84",
#             "event_type": "No Events",
#             "exceptional_data_count": 0,
#             "fiftieth_percentile": 0.043,
#             "first_max_datetime": "2017-06-09 10:00",
#             "first_max_n_o_datetime": null,
#             "first_max_nonoverlap_value": null,
#             "first_max_value": 0.066,
#             "fourth_max_datetime": "2017-04-13 10:00",
#             "fourth_max_value": 0.061,
#             "latitude": 33.801667,
#             "local_site_name": "Corner",
#             "longitude": -86.9425,
#             "method": null,
#             "metric_used": "Daily maximum of 8-hour running average",
#             "ninetieth_percentile": 0.053,
#             "ninety_eighth_percentile": 0.061,
#             "ninety_fifth_percentile": 0.057,
#             "ninety_ninth_percentile": 0.061,
#             "null_observation_count": 0,
#             "observation_count": 4148,
#             "observation_percent": 99.0,
#             "parameter": "Ozone",
#             "parameter_code": "44201",
#             "poc": 1,
#             "pollutant_standard": "Ozone 8-hour 2015",
#             "primary_exceedance_count": 0,
#             "required_day_count": 245,
#             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#             "second_max_datetime": "2017-05-15 10:00",
#             "second_max_n_o_datetime": null,
#             "second_max_nonoverlap_value": null,
#             "second_max_value": 0.065,
#             "secondary_exceedance_count": 0,
#             "seventy_fifth_percentile": 0.048,
#             "site_address": "10005 CORNER SCHOOL ROAD",
#             "site_number": "5003",
#             "standard_deviation": 0.010579,
#             "state": "Alabama",
#             "state_code": "01",
#             "tenth_percentile": 0.026,
#             "third_max_datetime": "2017-03-23 11:00",
#             "third_max_value": 0.061,
#             "units_of_measure": "Parts per million",
#             "valid_day_count": 243,
#             "validity_indicator": "Y",
#             "year": 2017
#         }
#     ],
#     "Header": [
#         {
#             "request_time": "2020-04-29T23:39:30-04:00",
#             "rows": 92,
#             "status": "Success",
#             "url": "https://aqs.epa.gov/data/api/annualData/byState?email=lilu216@hotmail.com&key=baygoose48&param=44201&bdate=20170101&edate=20171231&state=01"
#         }
#     ]
# }
